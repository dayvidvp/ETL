# %% [markdown]
# ## Load the paramaters and imports and set some variables

# %%
from fuzzywuzzy import fuzz, process
from loguru import logger
import pandas as pd
import sys
import pyodbc

global MSSQL_SERVER
global DATABASE_NAME
MSSQL_SERVER = "STRDVPDBSQL01"
DATABASE_NAME = "masterdata_steam"
conn = pyodbc.connect("DRIVER={SQL Server};SERVER="
                        + MSSQL_SERVER
                        + ";DATABASE="
                        + DATABASE_NAME
                        + ";Trusted_Connection=yes",
                        timeout=15,
                    )
print(f"Connected to SQL Server {MSSQL_SERVER} and table {DATABASE_NAME}")
# Out:
# Connected to SQL Server STRDVPDBSQL01 and table masterdata_steam

# %% [markdown]
# ### Querry used to get the data

# %%
def load_components_from_sql() -> pd.DataFrame:
    cursor = conn.cursor()
    query = ("""
    select 
	comp.[Server]
    ,comp.[internal_article_number]
    ,comp.[article_hash]
    ,comp.[componentname]
    ,comp.[componentidentifier]
    ,comp.[manufacturer]
    ,comp.[manufacturer_description]
    ,comp.[component_erpreferencenumber]
    ,comp.[implant]
    FROM [masterdata_steam].[dbo].[Components] comp
    order by comp.[Server]
    """
    )
    with conn:
        cursor.execute(query)
        query_result = [
            dict(line)
            for line in [
                zip([column[0] for column in cursor.description], row)
                for row in cursor.fetchall()
            ]
        ]
        df = query_result
    return df

# %% [markdown]
# ### execute the query and store the results in a dataframe

# %%
_components_df = pd.DataFrame(load_components_from_sql())
_components_df.to_pickle("components.pkl", compression="gzip")
_components_df.to_csv("all_components.csv", index=False, encoding="utf-8", sep=";")

# _components_df = pd.read_pickle("components.pkl", compression="gzip")
print(f"{len(_components_df)} components loaded")
# Out:
# 68824 components loaded

# %% [markdown]
# ### Check to see if the data is loaded

# %% [markdown]
# ## Manufacturers
# * create dataframe from the grouped manufacturers
# * create a csv document with the data

# %%
manufacturers = _components_df.groupby(['manufacturer_description'])['manufacturer_description'].count().sort_values(ascending=False)
manufacturers.explode().to_csv("manufacturer_count.csv", sep=";", index_label=["manufacturer_description", "count"])

# %%
_df_manufacturer_count = manufacturers.sort_values(ascending=False).explode().to_frame()
# print(_df_manufacturer_count)
_manufacturers_with_low_component_count = _df_manufacturer_count.where(_df_manufacturer_count < 10).dropna()
_manufacturers_with_low_component_count.to_csv("manufacturer_with_low_component_count.csv", sep=";", index_label=["manufacturer_description", "count"])
print(_manufacturers_with_low_component_count)

# %% [markdown]
# ## find similar manufacturers

# %%
from collections import deque
from functools import lru_cache

@lru_cache()
def process_manufacturers():
    _similar_manufacturers = {}
    _count = len(manufacturers)
    # _count = 100
    print(f"{_count} manufacturers to check")
    _ratio: int = 85
    _queue_one = deque(manufacturers.keys())

    # compare all manufacturers with each other and pop them from the queue if they are similar
    for _ in range(_count):
        _queue_len=len(_queue_one)
        if _queue_len == 0:
            break
        _manufacturer_one = _queue_one.popleft()

        for _manufacturer_two in _queue_one:
            _similarity = fuzz.WRatio(_manufacturer_one, _manufacturer_two)
            if _similarity >= _ratio:
                if _manufacturer_one not in _similar_manufacturers:
                    _similar_manufacturers[_manufacturer_one] = []
                    print(f"L1: create {_manufacturer_one}",end="\r")
                if _manufacturer_two not in _similar_manufacturers[_manufacturer_one]:
                    _similar_manufacturers[_manufacturer_one].append(_manufacturer_two)
                    print(f"L2: {_manufacturer_one} and {_manufacturer_two} are similar with {_similarity}% queue len: {_queue_len}",end="\r")
                _queue_one.remove((_manufacturer_two))
                break

    print(" " * 200, end="\r")
    print(f"{len(_similar_manufacturers)} similar manufacturers found with {_ratio}% similarity")

    df_similar_manufacturers = pd.DataFrame.from_dict(_similar_manufacturers, orient='index')
    df_similar_manufacturers.to_csv(f"similar_manufacturers_with{_ratio}_ratio.csv", sep=";")


process_manufacturers()

# %%
from matplotlib import pyplot as plt

_total_count_components = len(_components_df)
_total_count_unique_components = len(_unique_componentidentifiers)
_total_count_componts_with_gr = len(_components_df.query("componentidentifier.str.startswith('GR')"))
_total_count_componts_with_ir = len(_components_df.query("componentidentifier.str.startswith('IR')"))
# _unique_customertokens = _components_df.customertoken.unique()
#loop through the customertokens and count the number of components for each one

# _customertoken_component_count = {}
# for _customertoken in _unique_customertokens:
#     _count_components_for_customertoken = len(_components_df.query("customertoken == @_customertoken"))
#     _customertoken_component_count[_customertoken] = _count_components_for_customertoken

# _customertoken_component_count_df = pd.DataFrame.from_dict(_customertoken_component_count, orient='index', columns=['count'])
# _customertoken_component_count_df.reset_index(inplace=True)
# _customertoken_component_count_df = _customertoken_component_count_df.rename(columns={'index': 'customertoken'})
# _customertoken_component_count_df.dropna(inplace=True)

# print(f"{_total_count_components} total components found")
# print(f"{_total_count_unique_components} total unique components found")
# print(f"{_total_count_componts_with_gr} total components with GR found")
# print(f"{_total_count_componts_with_ir} total components with IR found")

# _customertoken_component_count_series =  _customertoken_component_count_df.query("count > 2")

#plot some data

# _customertoken_component_count_series.plot(kind='pie', x='customertoken', y='count',
#                                         figsize=(10,10), legend=True, autopct='%1.1f%%', fontsize=14, title="Customertoken component count",
#                                         labels=_customertoken_component_count_series.customertoken,
#                                         startangle=90,
#                                         shadow=True)

# plt.legend(loc='upper left', bbox_to_anchor=(1, 1),fontsize=12)

# plt.savefig("output/customertoken_component_count.png")
# plt.show()

_plt_df = pd.DataFrame({"Total Components": [_total_count_components],
                        "Unique Components": [_total_count_unique_components],
                        "Components starting with GR": [_total_count_componts_with_gr],
                        "Components starting with IR": [_total_count_componts_with_ir]})

_plt_df.plot(kind='bar', stacked=False, figsize=(8,6), legend=True, fontsize=14, title='Total Components',
            edgecolor='black', linewidth=1)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=14)
plt.text(-0.21, 0.0, f'{_total_count_components}',fontsize=14, color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.1'))
plt.text(-0.10, 0.0, f'{_total_count_unique_components}', fontsize=14, color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.1'))
plt.text( 0.04, 0.0, f'{_total_count_componts_with_gr}', fontsize=14, color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.1'))
plt.text(0.15, 0.0, f'{_total_count_componts_with_ir}', fontsize=14, color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.1'))
plt.savefig('total_components.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ComponentIdentifiers

# %%
_components_df.query("componentidentifier.str.startswith('GR')").to_csv("components_with_gr.csv", sep=";", encoding='utf-8')
_components_df.query("componentidentifier.str.startswith('IR')").to_csv("components_with_ir.csv", sep=";", encoding='utf-8')

_unique_componentidentifiers = _components_df.groupby(['componentidentifier'])['componentidentifier'].count()
_unique_componentidentifiers_dict = _unique_componentidentifiers.sort_values(ascending=False).explode().to_dict()
_unique_componentidentifiers_df = pd.DataFrame.from_dict(_unique_componentidentifiers_dict, orient='index', columns=['componentidentifier'])
_unique_componentidentifiers_df.to_csv("componentidentifier_count.csv", sep=";", index_label=["componentidentifier", "count"])
print(f"{len(_unique_componentidentifiers)} unique componentidentifiers found")
# Out:
# 61442 unique componentidentifiers found

# %%
#filter the componentidentifiers
_filterd_component_identifiers = _components_df.copy()

_filterd_component_identifiers = _filterd_component_identifiers[~(_filterd_component_identifiers['componentidentifier'].str.startswith('GR'))
                                & ~(_filterd_component_identifiers['componentidentifier'].str.startswith('IR'))
                                # & ~(_filterd_component_identifiers['componentidentifier'].str.startswith('Unk'))
                                # & ~(_filterd_component_identifiers['componentidentifier'].str.startswith('unknown'))
                                # & ~(_filterd_component_identifiers['componentidentifier'].str.startswith('Unknown'))
                                # & ~(_filterd_component_identifiers['componentidentifier'].str.startswith('unk'))
                                ]
_filterd_component_identifiers.to_csv("components_without_gr_ir.csv", sep=";", index_label=["componentidentifier", "count"])
_filterd_component_identifiers.drop(columns=['manufacturer'], inplace=True)
_filterd_component_identifiers.drop(columns=['manufacturer_description'], inplace=True)
_filterd_component_identifiers.drop(columns=['implant'], inplace=True)
_filterd_component_identifiers.drop(columns=['component_erpreferencenumber'], inplace=True)
print(len(_filterd_component_identifiers))
print(_filterd_component_identifiers.iloc[0])
# Out:
# 59337
# Server                                                             KPRDCSA01
# internal_article_number                                           9025006320
# article_hash               6903d9fdf40253dd6708891b4930bea5830dbd31573662...
# componentname                EP-FIT/BOFOR/PE/MPF\POLARCUP Reamer 57 [130888]
# componentidentifier                                                 75003423
# Name: 0, dtype: object

# %%
for col in _filterd_component_identifiers.columns:
    print(f"{col}")

# %%
#dict for componentidentifiers
_comp_dict={}
for i, row in _filterd_component_identifiers.iterrows():
    if row['article_hash'] not in _comp_dict:
        _comp_dict[row['article_hash']] = []
        _comp_dict[row['article_hash']].append(row['componentidentifier'])
        _comp_dict[row['article_hash']].append(row['componentname'])
        _comp_dict[row['article_hash']].append(row['Server'])

# %%
_lookup_dict = {}
for key, value in _comp_dict.items():
    _lookup_dict[key] = value
print(len(_lookup_dict))
# Out:
# 59337

# %%
def save_similar_component(master_article_hash: str, article_hash: str, id_linked: bool, name_linked: bool):

    cursor = conn.cursor()
    query = (f"""
            if not exists (
            select master_article_hash
                from dbo.similar_components
            where master_article_hash = '{master_article_hash}'
            and article_hash = '{article_hash}'
            and id_linked = {0 if id_linked == False else 1}
            and name_linked = {0 if name_linked == False else 1}
            )
            insert into dbo.similar_components
            (
            [master_article_hash]
            , [article_hash]
            , [id_linked]
            , [name_linked]
            )
            values
            (
            '{master_article_hash}',
            '{article_hash}',
            { 0 if id_linked == False else 1},
            { 0 if name_linked == False else 1}
            )
            """)
    with conn.cursor() as cursor:
        cursor.execute(query)
        conn.commit()

# %%
def cache_previous_processed_article_hashes() -> list:

    _key_list = []
    cursor = conn.cursor()
    query = (f"""
        SELECT distinct master_article_hash from masterdata_steam.dbo.similar_components
            """)
    with conn.cursor() as cursor:
        cursor.execute(query)
        for row in cursor:
            _key_list.append(row[0])

    return _key_list

# %%
from fuzzywuzzy import process
from functools import lru_cache
import csv


_check_dict = _lookup_dict.copy()
_comp_id_lookup_dict = _lookup_dict.copy()


_previous_processed_article_hashes = cache_previous_processed_article_hashes()
# remove the previous processed article hashes from the lookup dict
_comp_id_lookup_dict_final = {}

for key, value in _check_dict.items():
    if key not in _previous_processed_article_hashes:
        _comp_id_lookup_dict_final[key] = value

print(f"Number of articles to process: {len(_check_dict)} before removing the previous processed articles")
print(f'Number of articles to process: {len(_comp_id_lookup_dict_final)}, Number of articles already processed: {len(_previous_processed_article_hashes)}')

@lru_cache()
def process_component():

    global _ratio
    _similar_componentidentifiers = {}
    _ratio = 85
    _count = len(_comp_id_lookup_dict_final)
    # _count = 10

    for _ in range(_count):

        _t = _comp_id_lookup_dict_final.popitem()
        _componentidentifier_one= _t[1][0]
        _componentidentifier_one_hash = _t[0]
        _componentname_one = _t[1][1]
        print(f"Processing: {_componentidentifier_one} {_componentname_one} {_componentidentifier_one_hash}"
            f" remaining: {len(_comp_id_lookup_dict_final)}")

        #check if the componentid is in _comp_id_lookup_dict
        for _componentidentifier_two_hash, _t in _comp_id_lookup_dict.items():

            _componentidentifier_two = _t[0]
            _componentname_two = _t[1]


            if _componentidentifier_one == _componentidentifier_two:
                continue
            if _componentname_one == _componentname_two:
                continue

            _compid_similarity = fuzz.ratio(_componentidentifier_one, _componentidentifier_two)
            _compname_similarity = fuzz.token_sort_ratio(_componentname_one, _componentname_two) #Wratio is the weighted ratio

            if _compid_similarity >= _ratio:
                if _componentidentifier_one_hash not in _similar_componentidentifiers:
                    _similar_componentidentifiers[_componentidentifier_one_hash] = []
                    _similar_componentidentifiers[_componentidentifier_one_hash].append((_componentidentifier_one_hash, _componentidentifier_one, _componentname_one))
                    save_similar_component(str(_componentidentifier_one_hash), str(_componentidentifier_two_hash), True, False)


                if _componentidentifier_two not in _similar_componentidentifiers[_componentidentifier_one_hash]:
                    _similar_componentidentifiers[_componentidentifier_one_hash].append((_componentidentifier_two, _componentidentifier_two_hash))
                    save_similar_component(str(_componentidentifier_one_hash), str(_componentidentifier_two_hash), True, False)

                if _compname_similarity >= _ratio:

                    if _componentname_two not in _similar_componentidentifiers[_componentidentifier_one_hash]:
                        _similar_componentidentifiers[_componentidentifier_one_hash].append((_componentname_two, _componentidentifier_two_hash))
                        save_similar_component(str(_componentidentifier_one_hash), str(_componentidentifier_two_hash), False, True)
        _count -= 1
        del _comp_id_lookup_dict[_componentidentifier_two_hash]

process_component()
# Out:
# Number of articles to process: 59337 before removing the previous processed articles
# Number of articles to process: 57587, Number of articles already processed: 1823
# Processing: 28136 BT obturateur avec pointe L:200mm 142e8ebbccdb9d4651bb5386949ff3f239c1440d1c726062258c701e12775601 remaining: 57586
# Processing: 7111-2743 barre de fixation L:203mm 7355b3d3e44732e4d86702b3b503d19d49e70060a7e3dc35a8d50361e7b6f9a7 remaining: 57585
# Processing: 24.614.32 crochet L:100mm 846f43fd3b6cdfb8413d50a8499d2c4d4ac705fe9cdb4614bb876a46d135b400 remaining: 57584
# Processing: 26046 AA optique 0° 5mm L:360mm 96a97503b06861f9f3c5352c3a072cb5a0bbc95786aa9a7e9413f3ff0686da9b remaining: 57583
# Processing: 11.0031a Optique 0° L:410mm 37dd5e3a0475b97c04e6f3151e121f1da30d607783741ef5edf0d352dd9659f0 remaining: 57582
# Processing: IM220-020 petit embout pour câble lumière froide L:20mm d8977d4ea52fc62bd9003bd4fa8e1d5cfe8691b0a6fe0b630c557dd74f381306 remaining: 57581
# Processing: IM202-231 câble lumière froide 15da26d82bde1388e934ce24a9fddda85592d2b639126931ca03c8b0ab9a9f8b remaining: 57580
# Processing: 393.978 clamp fixation barre 565b853b68d4b884618fd73c4230333042f9a2cad121423dda3c30dc98ca9ca3 remaining: 57579
# Processing: 393.722 anneau ouvert carbone Ø 205mm 8e6a8b24720542041293a7907ce5cf03262722e294d9697f7bf6bd71be848b5c remaining: 57578
# Processing: K-05 tournevis en "T" L:180mm 5068faab8af9aaaec31f8db8a0b556fb28c68fe3a55adf9e91af190a6513e181 remaining: 57577
# Processing: H06 taraud en "T" D:5,0mm L:170mm 9d7927213adc4d869ec6c9dd7ad37c530a2a51079cd0a1073ca4e7f97daa262b remaining: 57576
# Processing: H02 taraud en "T" D:3,5mm L:135mm a9ac459637df3c9cbfa5ac784f041f9bc2a72aaa5c807c1f070392c15875303c remaining: 57575
# Processing: PK-141 Câble pcmk électrique 4 électrodes 74d4d906be71c35c6db364ce8b99d3dddc5590c06bb99f2bde2193cbc5f5dccd remaining: 57574
# Processing: D4240 shaver ConMed 0a50891073ea9f03ad7f5b2c37b80fd275bafb8439c764cc03bfcc0708bcb337 remaining: 57573
# Processing: 3815mer.ICD Pince anatomique bi-polaire verte baïonnette L:230mm 68d94dae1969188e767e5bc5fa755d80602a03c5719c1b8fb3a41ddf84661f79 remaining: 57572
# Processing: 11-2706 clamp de fixation 7cc58418b038119ccb3c42f86032b2f60683d32236ef4512359794de5f693ec3 remaining: 57571
# Processing: 11-2701 barre de fixation L:305mm 84359130ffa55cfced34a6f85220debcf60594d42761bace1d0b67391b042912 remaining: 57570
# Processing: 11-2740 mèche graduée D:4,8mm L:255mm a698da8591bc6fd22a540eec11da445d5dade8b836bb5263e05a9d7e7b63ee4c remaining: 57569
# Processing: 11-2720 gauge gradué L:280mm 85c9298700839368202b3b28e059805ea7ff15133cdec883c9842b71a0f4be44 remaining: 57568
# Processing: 11-2721 pièce en "T" L:120mm 703e0e7e19dc713f4368d6a7d3b005c017c2313e5d6314335c253275dd023a72 remaining: 57567
# Processing: 102907 clé à cardan L:180mm 87561ea68ba53d7199f047d6d50e37223094681d8b31772bf37d10e338cd3cca remaining: 57566
# Processing: BJ029R pince clamp Barré L:280mm 9f9427cff80e175ba55f2150c613a2079d11f2dbd266954d6d548011f170ec20 remaining: 57565
# Processing: 71031055 cle fixateur externe avec 2 branches bbdc8e0edc875f3368b2caf2be518dbb466de6b53d298ad4208afa87c109c599 remaining: 57564
# Processing: 398.790 bone forceps L:145mm 2237f70a2a634e88f75c599db67d24aac09a8a1fb3240f72d2219a6c77b1519e remaining: 57563
# Processing: 012047 pince duckling droite L:220mm df7e511540fc78e801c9070f389786ffe4b80cf41f092a996713fa668165b02c remaining: 57562
# Processing: B40240 pince dissection Barraya L:200mm 3*2 griffes 6335895c21dc3db4f4e111e5a23cdea274782d005df1e22d4ecb83893d318562 remaining: 57561
# Processing: 410059a sl optique 30° L:350mm dfa354a06400382239c23cde5482d2615861585e0c0008000fb25a9ea8df737b remaining: 57560
# Processing: 277 KB câble unipolaire haute fréquence 4521c3a8381d7105cd04705dd5ff159756365b8e5e151c62792e450a9fce5d1e remaining: 57559
# Processing: RU 7102-18 dilatateur D.17/18mm L:200mm 71bd1ba0396f36624e207925b19b90412d6994d2d88ca364bc3cf849504e7c99 remaining: 57558
# Processing: RU 7102-16 dilatateur D.15/16mm L:200mm ae3dd4b39993e71d866a871dee53a2323d969747f3b8c45ad8f3e0e6a6c54b7c remaining: 57557
# Processing: RU 7102-14 dilatateur D.13/14mm L:200mm f7e4587044019f3efa1a376c64cc6d903475f5fe3faed1bdb5b1ae1d4d4b9e97 remaining: 57556
# Processing: KB 744/36 bras forcep L plein L:360mm 56125cbf254b4e2b08bd37a1d2c0106ded35df8fa76d370ee3f276e231b3e695 remaining: 57555
# Processing: 07-650-32 cadre de Kirschner 2f20686012b9a62268740387f89b6a085458e0e320944b1b5bf74846993ad835 remaining: 57554
# Processing: 1002R pince à clips L:430mm 34707d5f923a6c4742407e43472e4da901e82f719e446abe9b1fa5c0a737906f remaining: 57553
# Processing: 30107 M1 valve pour trocart L:50mm 755c0df8879d1b702ceeb2d6afed71b083ec720146b6962edcf5a2f1d82f6400 remaining: 57552
# Processing: 30107 H2 trocart biseauté avec robinet L:160mm 08826f1c1d6a7c5270a008654643021a24e73a00d4b53899483365fdae285b59 remaining: 57551
# Processing: 30107 P trocart pointe triangulaire L:220mm 2c8e6d9f9331f488ccb54985f34faf61c1797074cc079d937794616068773108 remaining: 57550
# Processing: 26175 TH canule aspiration avec crochet L:425mm 7f73507ea04555161022ce0d54dc6e990261ce02f0bee48fa582eb68d557d172 remaining: 57549
# Processing: D254500107 base trial size 7 6e0e660dbfd05179adc839f0c280b54e5f9506b399fef66a940dfe608fc2865b remaining: 57548
# Processing: D254500105 base trial size 5 589f695318478c83179a8deb2c38f5f0de55534dad6ed1621f853f6b4e74f453 remaining: 57547
# Processing: D254500104 base trial size 4 08fec8abe6e72924cbf70a100913e39594508c1182df811a149d7c560b8435b2 remaining: 57546
# Processing: D254500127 eval bullet 15471b98b81f351e56855727375cfb7ba670455722299ef681b6ccff0e594695 remaining: 57545
# Processing: D254501053 Attune Patella Trial Handle 46765a187ef9cbd13cedca452465b3c0df9e26eae8b60afb7c88e38c77a720bf remaining: 57544
# Processing: D254501041 Attune Patella Modular Clamp L:280mm f3aaf2238a474d552550d48a95cc94b145c86180f5d2b49f3539072862adaf01 remaining: 57543
# Processing: 25-471-00-07 poignée guide L:160mm 28ea35cec214bab3d737c1e2669d3d1ac30450864b871e87bc5c1e4984463706 remaining: 57542
# Processing: 25-435-15 dissecteur double bout en "V" et boule L:165mm b56bc37be8c8dc0491f6d33f4a7fc080c7a629e403edfe32e51a025fdef3353f remaining: 57541
# Processing: 25-452-05 mèche D:1,1mm L:50mm 81005a88dc4e7f69dbdbc6fe6a07b62b0b02c27be217c459ef6ad6c51b2e0f57 remaining: 57540
# Processing: AR-12030 pince punch courbé 30° gauche L:230mm e3be29f0b408fb3523a4723394192e227676536e786597dcf032df6b0140b7bf remaining: 57539
# Processing: 012046 pince duckling gauche L:220mm ea3894f945382a296245222cd274b8417e606076aedd62576a8a96e80d6a599c remaining: 57538
# Processing: 5029-8-835 barre en carbone L:350mm 91e0c71752e19f9c9b492d04b18df05fa2f80b990726f5bfcc259b323557161c remaining: 57537
# Processing: 13 310 1207 Pince pean Halstead courbe L: 125mm san griffes a136d01c243d5b40bde6af6c3a0f60ac71548693713f21653a904891c166f987 remaining: 57536
# Processing: 154512 pince Halstead Mosquito courbe L:125mm sans griffes 6b49bf69ca955d3a34ccf74cbda299a48069490885c31b51245f70dff10e239a remaining: 57535
# Processing: FRC-15 RM-8 pince micro L:150mm 8mm manche ronde cou a17b080eed248c185ca83dbfe034e0c9372cf7320cbe8e6bd2c1050df4fd3517 remaining: 57534
# Processing: FD572R applying forceps Biemer L:145mm 67e5ff1b23a03474fadd115862710c9413375e7aabe7c305ad617f66f0875a46 remaining: 57533
# Processing: 32.213.15 pince gouge L:150mm fc70757268f66fa8a36486411bd16879acdff74b6da45eaf1b14bfe493cea817 remaining: 57532
# Processing: 03.226.004 tournevis amovible perforé T8 e88d3a41536f5d76710b2036cab6d34240480411cdf17c0da6eb15118716986f remaining: 57531
# Processing: 310.221 mèche perforée L:150mm fc5d5609fdc7ae00c659b20d66948eb15d0af3436a2a936c0272c5fd5262a065 remaining: 57530
# Processing: 03.226.002 jauge profondeur 7ebdaf3ca007c37953df95c40234ef3b999f3d0cabaa0acc45f0d76d5fa44eb8 remaining: 57529
# Processing: 292.623 broche conductrice D. 1,1mm L:150mm acier d8ae130cd629c3981d75d118727c37bc4370c89c045c63a9a46e552eaba190da remaining: 57528
# Processing: 292.622 broche conductrice D. 1,1mm pointe-filet-trocart eb32ad198bd7275a9caa1be7cfe43c48a88690da2c07c161785c6f3c1ec97412 remaining: 57527
# Processing: 03.226.000 douille-compress D.3mm 2ba665999acbcdee1bc2461c63198c1f745200882061cd53d7c64dfe2f9cac32 remaining: 57526
# Processing: 03.226.006 poignée pour douille-compress acd12d06631bfff2ea5a9547ffc57d8d1198b14fa1c5551d4d11b42cec43a2a0 remaining: 57525
# Processing: 312.151 double guide mèche d7631e54443368e332173bd49c70b302ddd54084bb047728393bb187539d3213 remaining: 57524
# Processing: 68.226.010 panier avec couvercle pour vis 52a602c8d094815976df8a30af246b8c09c625b24ae741d5e28924883af3fc60 remaining: 57523
# Processing: 319.292 fil nettoyage D. 1,1mm f1aefb90dc025868256a7a52432ac52f276a1da6fe31d83e2df4b9c0731cbbf6 remaining: 57522
# Processing: 319.291 brosse-nettoyage 3ec5165c6d4fdafd672321d3f2288e79744f300c3f882d2e77cc8baceabc14ac remaining: 57521
# Processing: B2308 pièce en plastique blanc L:40mm d5523842b2b92fe5be0b813ccf3c36439cf05aa2600d69afd3d9092986459fb0 remaining: 57520
# Processing: SP5083-131 pince ligamentotaxor L:170mm 290ba02e5e5522cb3e9fa83cedffb2bc893efda9c493f5fbce680cd720025319 remaining: 57519
# Processing: 323.201 guide mèche D.1,5 / 2,0mm L:120mm a9402beca26818f2d2643d7f84b76c6cc6a33fe100e0607ff565ceb3f71ab2aa remaining: 57518
# Processing: 319.134 guide mèche D.1,0 / 1,3mm L:110mm ffe868bc49923a0c77ea432947e94803f22846e2a8ea4a17c64f956a2192dded remaining: 57517
# Processing: 313.97 gaine tournevis L:25mm c199adae62a5167afd09dc10de4c152c4c7e0bef7b90307fc1333e6189200142 remaining: 57516
# Processing: 319.006 gaine mesureur D.2,0 / 2,4mm L:85mm 339d2e3e4ddc6635eecce4c223f89e73070dd71285c58b168de9eaa143cd1400 remaining: 57515
# Processing: 319.004 gaine mesureur D.1,3/1,5mm L:85mm 72a40c8e9ede837a0ce263093348a7093346b629316c5b6e0ad8622637075473 remaining: 57514
# Processing: 311.01 poignée verrouillage rapide L:100mm 0e08af6fc97d338d85f708a743c5a1772a112cc6059dde72c5a7c9b8fa1f4073 remaining: 57513
# Processing: 347.985 pince porte-vis coudée L:150mm blocable 7faef71f3e00c302436a891352f216cffde228cfd617df7f64624a8a2ffa60ce remaining: 57512
# Processing: 398.819 davier à pied pivotant L:150mm a332c3152bdb07408b39c1601fca2a387d5e7d7809883ff5784db30bf989838c remaining: 57511
# Processing: 398.950 pince réduction L:90mm 63bdc0a3de401ce07cce23b6303e1f9ec59e621103dbf83ea2826d57f9d4b585 remaining: 57510
# Processing: 313.96 douille de fixation L:195mm 848398dfa7b97aeb639d1f336b39e6efc7f1fa0d88332f62fc1627e1a5b1ed79 remaining: 57509
# Processing: 391.963 pince à plier plaques L:170mm 70111086b72ffb2809c78aa7d4076e070158a2e0335cd4e8767ebd4d831da3ef remaining: 57508
# Processing: 391.962 bending / cutting poiers L:205mm 242e0a64a9cf2e4d88dbd5f1fba48a2cef26a2717ef4d3bef7e92a5910067e46 remaining: 57507
# Processing: L594985 gaine tournevis L:45mm 5af8f48abea75dc04620bdff3fc55b4cdd7244190b99adc4b991076889e5290f remaining: 57506
# Processing: L551732 tournevis D.2mm L:70mm 823e378f3447e911c232aa9440a83706fdb1518053a1d6b57285ae9bbf5ef6a7 remaining: 57505
# Processing: 310.971 fraise à chambrer D.1,3mm L:50mm 07d91045f2c1ce8f4c6e2949e0543032295a63036527e6f7831d2d5c38c31742 remaining: 57504
# Processing: 310.111 mèche D.1,1mm L:55mm 3a3426b73f95440d23af063ad76d3b3c42119831f8f2ae807f7012ebb099821d remaining: 57503
# Processing: 399.003 davier réducteur avec guide mèche L:190mm 74e94ecb304238435e0451c247f5f803c8bb3e5792fc11625263793e7ea15a89 remaining: 57502
# Processing: 2821853 tige creuse L:60mm cf919db7c5bd2ad46e7ce0c9b62a418aa56d25453eaba5f27a131b099d6a2788 remaining: 57501
# Processing: 314.670 manche tournevis L:37mm 042bda6f28724c6c8ff2da01d4c12ed0e671d1af1d0bb747b39ac1380b981c7f remaining: 57500
# Processing: 1133429 chemise tournevis 2mm L:45mm a9761f4aa7ccb44f14d9b1a07f510efd4df519902b595203f51bd437a709a768 remaining: 57499
# Processing: 310.972 fraise à chambrer L:55mm 5f13c9169e799c628a6570dc324d626899a956699139b24136dc96f211444ee0 remaining: 57498
# Processing: 310.141 mèche D:1,5mm L:65mm 7dd52cba476a178963be3b135c2c22d7775ef3418d936f4a1c2af206f0b7203f remaining: 57497
# Processing: 513.140 mèche D:2mm L:65mm 001dc4d9dabdbfaf20ee19fcd1e1d9b03937feecca1859c53be2b35ea55da5f2 remaining: 57496
# Processing: 14.30.17 pince coupante L:175mm 7be45280ac092e81eef8bcfdccf7cc1854f670486516193578221812f53675dd remaining: 57495
# Processing: 5827-20/03 pince à tendon courbe L:150mm 4830a6145f987dc59a1141304d391e98c48d637cc51e689a3852b2b51c124083 remaining: 57494
# Processing: 5827-20/02 pince à tendon droite L:150mm 41316bbeb51b639e721d0d48ac39b5fac9f5b577189d4bc9db23712db72603ce remaining: 57493
# Processing: BF320R pince à tendons L:210mm ce6ff0ba412c27cfbc08271c4fc4b82feae131a368ff561a5594c7f2e1e7ee44 remaining: 57492
# Processing: 08.609.17W ciseaux à dissection courbes L:180mm 623fa260e31c3c0e8f764375cc0a06d852276a3edc20bcda76204f4a85c0d59e remaining: 57491
# Processing: 30310 UL insert gainé pince à préhension Reddick-Olsen L:370mm 693edd8e5ca5187552e1d9428cb52635d8b85a256e550229fd7aefdd925db9ea remaining: 57490
# Processing: 30310 R inser gainé pice à dissection coudée angle droit L:370mm 44afe9ea7663b23f86cdc264f6d33dd1dab76db096d2082c5df222773be90387 remaining: 57489
# Processing: 30310 KS insert gainé pince à préhension fenêtrée L:270mm 4fd8e9130d4c4f2808a46ecc12d64a8cea7950634ffc269ce05becde8bb366e7 remaining: 57488
# Processing: 33161 poignée click line sans crémaillère 236b662f1a535fc944b58ba794b88a82a26ed7dede9dfda7817f852e23528019 remaining: 57487
# Processing: 30141 AA valve articulée 1bfc29aaf74b0689103e9619dc81bd9289d5d402a761f4652ac49aa2ac4a1b43 remaining: 57486
# Processing: 30114 K pointe triangulaire L:110mm 7453328477c63374fbfb4e442933e42289e8ddc2b2505e0da7517710bf0770ba remaining: 57485
# Processing: 30114L1 capuchon vissable pour trocart 69661564b5ca34ba5b8f353e37bb84af1bd83114db3e7e77d48829ca1be47e5c remaining: 57484
# Processing: 30114 G1 trocart biseauté L:80mm Ø:4mm d5b23c52ab042eb9596f578ec150ae5fdcad93c0c59d1ef66dba0343a8d16776 remaining: 57483
# Processing: RU4822-01 petite valve pour cadre de Kirschner L:180mm l:55mm 4bc0be7b945de085b1ee0d9849bf646eab2350fbe7afe3e22d0cf04374fc0320 remaining: 57482
# Processing: 03.06.13 ciseaux à fils droits L:130mm c354b6800ecb44e0a91186decbc34f573b514cdd2a8ee061a876ed6229437a1b remaining: 57481
# Processing: 30120 K pointe triangulaire L:120mm 236f4c3a528969e35fec932b23970e07564dc2a63ef45b921d8b2c2b2c4ddc0e remaining: 57480
# Processing: 7004-660 tube de canule d'aspiration L:340mm a828f0b131836ea567fa94b60aa079524805ee5fde9a84760212ada54e545b8c remaining: 57479
# Processing: 201704241 insert mini Metzenbaum avec gaine L:380mm 6ad7051e43d6a653211333e51d5ce78b1ead30c83745fb0e8be84049e1555630 remaining: 57478
# Processing: 30103 H1 trocart avec robinet L:120mm 0bf7020093445e321b3dbfafa8a0b8d4223014b8d504a71f306c23336ca3b3f4 remaining: 57477
# Processing: 30160H1 trocart 6mm L:115mm 03ff9fcbe608932378787c1a4598ef15e44c5dd0d1352452b52dba05d3af8d08 remaining: 57476
# Processing: 30103 Z pointe triangulaire L:190mm 6646643a01de41d881a5edff4671947da079ac5b1c6172a786f8ff16ab230ad1 remaining: 57475
# Processing: 30160 Z pointe triangulaire L:160mm 59399d9c88c578eeb24329b999bc63a4ce01efa28520440e0d7abb7a76eb22ce remaining: 57474
# Processing: 26173BN canule d'aspiration L:420mm c9d7263421a4af333329b5a2103cca5205a7a01fe87db0fdc04592f604a64c7e remaining: 57473
# Processing: 203501 crochet f5415f8c480e363aeed50e84b0278b034953636665da676e9d8fbc4b6d10d019 remaining: 57472
# Processing: 120-091-105 ciseaux courbes pointus L:105mm 710b515f9ce3ee6830398ef2d778b7f46b58d1199c26bc8ec6bae0e884a91489 remaining: 57471
# Processing: 22006300 Pince dissection Adson 2*1 griffes 1ee20a701262a0793374ace7468032d34658fc160339e86569c76a90a51dad9b remaining: 57470
# Processing: C38780 Crochet L: 150mm b9dcaa5e280d55846acfca925b7f54d8af63a1897c48d28414645f3d8f687079 remaining: 57469
# Processing: 4360 cuillère à hernie L:150mm b9a34c4bf85ab30527d8413bad1a47199176ebf221bf81b51ed201d72e192c43 remaining: 57468
# Processing: 6297-15 crochet L:155mm d1357ce6ef423303f3fde6d2740e51849c05c012efaaab91765e9913cfe068ff remaining: 57467
# Processing: RU 605515 porte aiguille Mayo L:150mm 15b60bf8d4a29c7edb1b6280b2113c21c261b507bd416b54b57d74131488294b remaining: 57466
# Processing: AE 100-16 pince dissection anatomique L:160mm sans griffes 4c528ae9bd98f9cfb1b126f6d04589e90043f6e4e36cf192d06a2eb6d248753c remaining: 57465
# Processing: 13901 crochet L:150mm b410fe5fd2cade718c437dcf92e0da191671db2d42e562dfb820fcfbfb8ed011 remaining: 57464
# Processing: 04-260-16 pince préhension intestinale Williams L:180mm 6167b1150de1443a3370718875232676d6016198885ed35daec6478b1a1d9e74 remaining: 57463
# Processing: RU6557-15 pince à sténose L:160mm acac0cc03108bd6a9fa01d6c3b27b1999c09de76e678d3fb2f251b713c37e525 remaining: 57462
# Processing: 29509 pince micro Adson L:120mm ddedad2bec0aba8dddc14e74ae361546c46dd25a24caeaaf6572caa14e309621 remaining: 57461
# Processing: D-5aZ micro pince droite L:115mm 0376001ffa9858d689cca28111682cbc578e0b612a4dc4844138d2fd24970749 remaining: 57460
# Processing: ABB-2V micro clamp double L:15mm 1dde6fcdcc276435d69ba251f77d6657ca792d4a385e3c8b5fd3ac7b3a498fc4 remaining: 57459
# Processing: 3V micro clamp double L:18mm f8c62848226a1c9284f0f1750fb261a269053c5b62d8d68cf002f517e0bf3319 remaining: 57458
# Processing: C-14 micro pince courbe L:140mm 8fe2f43ba8203b402edc05b4b50a5830b2edc2fc2e4fd087c4b3ec898879aed4 remaining: 57457
# Processing: JFP-3 micro pince droite L:120mm 3710275668b3c4ad10580a380bde1e57f413b7258e52e40b572168d4fd14fe50 remaining: 57456
# Processing: JFL-3 micro pince droite L:135mm 61698a1d0fc32dff218c6033a3ad23ffa7aa8b719cfa1986e7787846acfcd37c remaining: 57455
# Processing: 39523-30 câble de lumière froide 20696e5dfe527b3a3b6e6c5def9df6f42ee5b4fc0b5d55e79a919a7d61f7f857 remaining: 57454
# Processing: 27032 E cystoscope L:195mm ae8c67a06d0509fccae9630f6a75396667c6d0b633ce1256c099dfc2bd0bc0d1 remaining: 57453
# Processing: 64.210.18 pince à champ droite L:180mm 0b59c579b7bcd1e39f6b62d0bab5e02830927b2b97a975c7a26aa5bc3a465f29 remaining: 57452
# Processing: 60.159.13 clamp DeBakey L:130mm e40246d9db8c99679bb1d1ad85f489829cbd27ff87f134791c6dd89bfbf1eaff remaining: 57451
# Processing: 06-0281 pince Bengoléa L:215mm 60d12273daa0db5c60d6f8f416d78a2e054bb8e2a3facd46e92578c16b4173ff remaining: 57450
# Processing: 3097-09 pince baby droite L:100mm fef84c2bcae90f33f24ae893deddb3528de47e4b07f9659f4e42550938a232eb remaining: 57449
# Processing: 24.225.18 porte aiguille fin L:180mm 1872c69b3fb37bb4a8349661db0284fc94bac4427507bf25fbcb7201883bf0f9 remaining: 57448
# Processing: 50 503 Ciseaux pointus courbes L: 145mm abb2c4b11ae0825e8e1fcc34e6a0f3acccfab58c461f89a0740ea006d1814314 remaining: 57447
# Processing: 10.325.15 pince anatomique à palettes L:150mm a676d73f4fed94734d94d0dcd2fccb5b5d9bd65ddf0b6f421e1217bfb7f88c93 remaining: 57446
# Processing: 27301AA optique 0° L:165mm 440129e10842a9e2f08227f95095d6b43b2328b60ea502bae941cd6d907fecd0 remaining: 57445
# Processing: RO1/13 dilatateur fin L:200mm 0c967859be421249b49d1449f048f72cb6a3cecbd4023647568bbd48ec651a44 remaining: 57444
# Processing: 15-381-01 valve petite double L:260mm 0d8a5e514f521506097718dc894c4a5afd5d8c4809732419f8b08f6fd0f175c1 remaining: 57443
# Processing: 26173 CQ port aiguille laparo L:480mm a14bc4251974647f799845a843b0e3fdeae39912a3ab5568641ccd393094ac2c remaining: 57442
# Processing: AVS08 Pièce à main bague rouge 2263d7f4d0e39803682b5797c58dcca563c375e043e71c91d25c1f2826c58158 remaining: 57441
# Processing: 1000 RPM perforator driver attachment e6278cdfd232b6545235297329263c8485834c52d9e2ea84b4e4a87c57a4f8dd remaining: 57440
# Processing: 23/5980 Câble de lumière froide fa2611c82f704a66d1d2bacf36032c453bc3f4b1eb23a428d11a7883fd31a8a4 remaining: 57439
# Processing: 30114 Y pointe pour trocart L:115mm 581ef0d25119326179b92226d232045c634f10f2050cc1e9b035415fb70452a2 remaining: 57438
# Processing: 30114 A1 bouchon à click pour trocart ab3b0dc291d62d1a5076e65206ee726bc66d4427be83a1dfd91eb6f3e8a4823d remaining: 57437
# Processing: 30114 H1 trocart L:90mm ad8e8f972b4a41d0cb1eff2c96ea1c07e5b920328fba4dee315d15ff47e756e2 remaining: 57436
# Processing: GB034800 clé de serrage Jacob 043fca50534b63fc215c2d621ada61a2e07a9cf43b8088e3bf16725b80aba0d4 remaining: 57435
# Processing: 13.325.11 porte aiguille Crile Wood L:120mm TG a76482561eac98dc27d4113a9474e6155f4b2fcbeb5ecdb06355f442551294fe remaining: 57434
# Processing: 210.09100 ciseaux pointus L:110mm f1f7fb58df49ea3f2306357dac3722b697406ae8f90fb6e05215ab24eb2ae3fe remaining: 57433
# Processing: 10338X pince à biopsie L:390mm 241dd26fe6b622c1b41ab69d1ba9582a50a4d828e2f6bfa34f19de03d65d1aa5 remaining: 57432
# Processing: 10338U pince à biopsie L:400mm 626ed0df54056693df887696d63f509083e75636eef5d9ec69f94ffe0ffcc163 remaining: 57431
# Processing: 27071 TJ pince à extraction avec double mâchoire f200a54ac599b17afacb1e5f3b396e3f69ffc8458ba69aa82f2dcd82805781b5 remaining: 57430
# Processing: 27047 F insert d'examen avec entrée verrouillable 339e7669c4383ceebf65588c4507d8a0702d727472b3e46dbebfbaf0ffc383ae remaining: 57429
# Processing: 27147 ER anse coagulation L:170mm 6dfb30d27cb842f9ad8485ed75d55fe8cc869ca5c9821dfe7c9ce4c1b57e4157 remaining: 57428
# Processing: 27147 EG anse coagulation L:170mm 3dbabf9ad9809f4ed1b7fa687f8a9c74e508e24cfa8503a1280b8df221845ede remaining: 57427
# Processing: 310-291-180 pince à champ de Kenu courbe L:180mm 22f4d60b436dc658aada7251a98dca1072a011b9f849df5696b42b3c8d8ba3f1 remaining: 57426
# Processing: 64.160.18 pince Babcock L:190mm 2c4210b5ef1c606ea0809bbbf37595a52ff5021ad96a05d4e437cdc9c56d22d0 remaining: 57425
# Processing: 08.283.18 ciseaux Allaines courbes L:180mm 95c0bde4f4d525cd61011980ed41423e219707cb1cf9daa49c66d2169c480fe9 remaining: 57424
# Processing: 08.341.09 ciseaux délicats pointus courbes L:95mm 48024745bbf8fad45740d816de8b566436a597aa9dc62ddd1d35d789fd6252c4 remaining: 57423
# Processing: 27029 cysto-urétroscope L:120mm 251b353ec510c36606a9bc68c34012737374c7c7688dee12ba4676d59831bdbf remaining: 57422
# Processing: 072.715.11 écarteur Finochietto baby L:130mm titane 2055cca0558608ce7a688525f773638f50fad921f3a52dc0500719250c42b7d4 remaining: 57421
# Processing: 18.771.02 écarteur mousse L:140mm 2aac0a2926be29105c21c96d0764a2ce2c012bf2e9268a2297a861476e7d5d3c remaining: 57420
# Processing: 18.159.70 écarteur Kelly L:260mm 70*60mm 5250d98952185cce4e531f6090836734beb93791a355535717a626721481bb63 remaining: 57419
# Processing: 18.159.64 écarteur Kelly L:260mm 70*50mm f5a7b233621979bfb2649afb0e168ebdd795b86ce602245ed62883fd94c071ed remaining: 57418
# Processing: 18.159.50 écarteur Kelly L:260mm 50*40mm 9e2a2451ebaf154140263f1d22aa81f3f383fb5e5a6934c36f73e5bb4d2358de remaining: 57417
# Processing: 4827-10 grand écarteur abdominal cadre 44a21fd197c44e97b87383cbe28e9c580cac8bf0b8e98df0cae3a4ac3992f5fc remaining: 57416
# Processing: 4826-10 petit écarteur abdominal cadre 604a6b4a6c1a5cbf1c19fc794d7c24e2fc4c8d318bec661b5822134c693e7fd9 remaining: 57415
# Processing: 7516-00 écarteur Finochietto L:180mm 633e2c315996867e889384fdb603239c6017dd8c7050cd4749f2d87ba7a3619d remaining: 57414
# Processing: 27031 D explorateur CH 10 L:200mm af21fc57181edaa8aa61cd85344388d26c220b1ce9d95e0beedc5307a7634e57 remaining: 57413
# Processing: 15-1192 manche métallique L:75mm ae7c744a38e3400a45ff360a274510f8632e06e4ff2b39e33c5a6ed430000585 remaining: 57412
# Processing: 15-1191 embout tournevis hexagonal à clipper L:30mm bfa84b0734881c6f9b68a528a46cf74310fbd00959da0a3ed53a4c268c3156af remaining: 57411
# Processing: 433 pince coupe plaque L:125mm 671c900a29cc910cbe478ec929402b3befec330ed446390177b5652223f7c294 remaining: 57410
# Processing: 30173 A insert porte aiguille L:400mm f99ac8900acb764f3b1976cbe0c1dd652a5dd8e3e17c2022e9172f28a63d493b remaining: 57409
# Processing: 30173 AR manche porte aiguille L:155mm d7c991cb55112e5cb54d21a8781c545e4f26b33566637cc4b37b17205259e927 remaining: 57408
# Processing: AF01R footed attachment - rotating fb646f898fe5858e6d4c0bf9d416a8847feedca5a0b4ca010d40ffa8b673db55 remaining: 57407
# Processing: EM200 moteur midas rex avec câble f6898868aa94189b679a8e84faa7f813b14b6a9d47fbc935da87237cf58e4e1b remaining: 57406
# Processing: 27047 E chemise de résecteur L:140mm 2919b677e1578ed6b04da0e62a62b6d508a0124bb358ae97ac2d7c8c43dc36d9 remaining: 57405
# Processing: 27047 EO mandrin vert L:150mm 7f2daf52ae08eead9b0f6e0ab88a6ab557aa5700eabd7c4110cc799d5bdfcff4 remaining: 57404
# Processing: 27145 E poignée résecteur cb54614b4777c9ffbde84757a97e05fd3215341959656e4f67b24f6a1a3f4341 remaining: 57403
# Processing: 27033 ER électrode de coagulation L:195mm 842b52186124493ad4ba2aa2304d49f71c3597781d204a79e577399598f323a8 remaining: 57402
# Processing: 27033 EG anse de résection L:195mm 047c1a37edbe599a75085a696009cef06e438a6b82c233ef9cea0cfc5451e0b7 remaining: 57401
# Processing: 27033 RO obturateur jaune L:165mm 8aacddb7cf6445cb06874572d9a94ea07a0d6ba9f88465ab8fe6e6dc4d01539b remaining: 57400
# Processing: 27033 E élément de travail b32f591d80e89e87db6b0984c1e50120e4d9c17c77eb05c02239eeffad1f0ce5 remaining: 57399
# Processing: 27033 R résectoscope CH 9 avec robinet L:160mm c55c9342d848f3d258b401cb1a3d57da10789c0e4ed69dcae5c3a54b4523117b remaining: 57398
# Processing: 27033 AA optique 0° L:285mm df2bc75c4263c081cfe8f5ba8ab18aa573a2901f54d7f7cac0e8801914164f20 remaining: 57397
# Processing: 495 NTF câble lumière froide(PAS DEMONTABLE) fe96a5b0b6cebafbeb7f3be376f59277333afc997e9b06a49089751ffac13ef2 remaining: 57396
# Processing: 26.48.01 rugine spatule L:170mm 195e44fc003f91696c512ef991b47d59fa1eaed6e61b2cda66af5aea31cef9a9 remaining: 57395
# Processing: 27.61.68 gouge 8mm L:140mm 5ccfe103ae0bdc82e2e8d21664173fb8133c4553b64fc0741d39c4662bafdecf remaining: 57394
# Processing: 27.61.08 ciseau 8mm L:140mm 6b6f35c39cd15954450e37cf6d80a03c1b4045c729b82878da880e7a9de47a88 remaining: 57393
# Processing: 27.61.04 ciseau 4mm L:140mm d861773cfe5fb8782e4b338fe951943a152a3c1a6e34fd3f26af629654ce5411 remaining: 57392
# Processing: BV5 écarteur 4*3 dents avec vis 5289ce6cfb3d18b2c01ae2d5c0171e5790f37078a14ae76874478dee06d17fe1 remaining: 57391
# Processing: BV1 écarteur autostatique 2*3 griffes 91d649116f645e6d85a05fdea25473118ea91278a9b2f4811cb540161434cfb3 remaining: 57390
# Processing: 22.00.25 lame malléable L:200mm l:25mm e7575e09a596f19e7a9b04d37999a32885251a6ffaf74f177d1bea395632a4c6 remaining: 57389
# Processing: FD396R crochet L:190mm fc6c51d27c5a27e34d1b988673e04a5b6a00b5a2844f6bd5ac4e144c780b6151 remaining: 57388
# Processing: 57.36.01 dissecteur double L:200mm dd33b515a6fcc9ec04ff7db5763f56e942b5dc529af273711e1c5e24ef8321c8 remaining: 57387
# Processing: 57.36.14 spatule double L:250mm f54c5214ef27cb43f5a4db1ef5a146784ae2a0ffb371da422539d55547644265 remaining: 57386
# Processing: FK659 curette tranchante Williger L:170mm 8a8ad1d9ab2755aa5db65d0c45242e0f2a63437eaacaa8b4185954858cef0e3f remaining: 57385
# Processing: FK658 curette Williger 3,4mm L:170mm 3409b99f253581e3cfa3abec5d8d2a5614501018f3eb6c1b3cb996a3fdd77ed7 remaining: 57384
# Processing: FK631 curette de Volkmann L:170mm 50bfcec50e11d27169ea7a06eb788fcbf34cc61d62bda54228c83676cadc75c3 remaining: 57383
# Processing: PO18-1048 pince mosquito baby droite L:100mm 6ff026a9e61a660cb209611620dc7a7d50196b909ec7403c489fa574936cac20 remaining: 57382
# Processing: 081740 Ciseaux Smits Davier L: 140mm f2cc82817b9a4d1847909a18d9749295fab1c71fe9958cdf07e7d18c1642256a remaining: 57381
# Processing: PO14-2416 ciseaux droit L:145mm 0ffbb36e56b9443b1596cf5c03668a6e1832bc9752a9c1457facfab7601522dc remaining: 57380
# Processing: PO18-5003 pince Debakey L:155mm sans griffes e6e7df6c0cf1afb5e8d994c16c82ca783cd75ffe1eafbcd1603c9a93fe5af2fd remaining: 57379
# Processing: PO10-1015 pince Debakey L:145mm 2*1 griffes f7277fb2069d7b4aedef2569a38f44b59818ea69fa831c3249513696cdddb4b2 remaining: 57378
# Processing: PO18-5025 pince Debakey L:125mm 2*1 griffes 3bf6515835a27e5e231f42fc6647b1fb117380c60277f6d2c140814314316963 remaining: 57377
# Processing: C9AZ33002 Pièce à main avec câble ultracision 609937d8eeca28ab78b55091829c2302c02b8075483536bae9e9383db7b2d75b remaining: 57376
# Processing: 27032B cystoscope avec 2 embouts 32882c88b90fb6a34b554de00aed789574b1458bddb9473b38b3b9d5372d4f6c remaining: 57375
# Processing: 27032 C cystoscope CH 13 12923b7d9e11c71a3800dc8e020a4868400eeb36e081637b1de9baacec6808fd remaining: 57374
# Processing: 27022 Y insert cône L:20mm 24be3cf23e421366fa07bddb6e6dad9a8888d7e567805b00cafa75d022d2a12a remaining: 57373
# Processing: 27032 F insert d'examen 96abbaffc5e69d3e6b4e96ff00fa1dc4abdadcb9395054ff2f20e957394348cf remaining: 57372
# Processing: 27018 BA optique 30° L:230mm 5ea176a9f96ee85d22357532675973303e56009332649a03a5fa733aa8d6a69a remaining: 57371
# Processing: 10-914-10 Crépine L:190mm 4ce80891410808d09eaffb626dac4459194b5714516ee5132af4ac646ac499e9 remaining: 57370
# Processing: 03-419-21 pince Overholt courbe L:210mm 56a2b3679f1afd8980f843895c0eab1500b9c392209e483dc494b95c7ba1aac1 remaining: 57369
# Processing: RU 1261-21 ciseaux à fils courbes L:210mm 90c64cd36aee0d306a4d6d27a0b2b1d4dc0f12433cff5ba9b7c4f542a1127acc remaining: 57368
# Processing: 02H001 canule n°3 3 trous L:270mm 468c909b6eaa7169818d82cf19df8d4868869c8e943f39c8863673bd2a943f4d remaining: 57367
# Processing: 6541-25 clamp intestinal courbe Mayo-Robson L:250mm c9a47d1f54222ff0f965a8a9668726117ccc925a92099e2b67053d0cbde463c6 remaining: 57366
# Processing: 107-12370-20 pince Babcock L:200mm 18b90d6f346a20f834269c68e792c33324ade5be902628f72497cde4d3544a07 remaining: 57365
# Processing: 15.220.19 pince Babcock L:200mm 0ae369faa667e454f9345269d8b8823d332674989a5083939c5e656175cd37b9 remaining: 57364
# Processing: 1334-25 ciseaux dissection courbes L:260mm 73c65569bb92a4ee883dbc5c99c7eac79f0f77018e6ccb008dc5fd128361e19f remaining: 57363
# Processing: 2091MC ciseaux courbes L:230mm 71cc9b329ef226375e86a2635cc9ec7c2188810692ceaf5b4fa4777b54f09f0d remaining: 57362
# Processing: RU 7580-30 pince anatomique atraumatique L:305mm sans griffes 58ba6737269e9d53834865ef60df5b85b2110aba9c3be344e3cf1257c40adb69 remaining: 57361
# Processing: 5280-22 crépine L:190mm d8a2422bbb9cde4310d55d4ffb76bb60552474a9396b938ad243ab57d58f3209 remaining: 57360
# Processing: 15.377.23 Pince O'Shaugnessy en "S" L: 235mm eb795860f0d818e81556c62fb00d8846b3051d2763433c96217a85dc371d4ae2 remaining: 57359
# Processing: 00763G pince en coeur étroite L:210mm 0756ea00688885ccb2068dbba7bf87d24928b1950e348b54085ba3e0a37ac685 remaining: 57358
# Processing: 11.171.21 Ciseaux courbés L: 210mm 9ca9dfa049ec091aa7bdfd4fb928a2d8e3a42c6b10750a290ce3e1aa10b1e50d remaining: 57357
# Processing: 69898 aiguille stimulation 150MM avec câble 65a8d144e90f6ee7e28215acccfacf72d5c8d86b2dacde4a15f7bc83b4c4f959 remaining: 57356
# Processing: MAJ-855 tuyau d'irrigation dfc8bbaad9eeb8f3712fb31dcbea64daa818adb9a2ae0ffe6e769cb8269181d9 remaining: 57355
# Processing: OFP-2 jerrican pompe d'irrigation 7750c0b43de54170564aaa49aa37eb7cb554cabcd25dfa4423cda59d2e63067a remaining: 57354
# Processing: 02.04.10 ciseaux de Stevens droits L:100mm 65e98ab537afbefb42a95ab029ca58bd9d7dda3628ebfaef515256cfaf79d4ce remaining: 57353
# Processing: 10-102 pince dissection anatomique L:130mm sans griffes 43786fbf965ed8766efed7cf01e8931af37d5468bed04b153f687d3a913d1f3c remaining: 57352
# Processing: RU 4040-12 pince anatomique fine L:120mm sans griffes 350e0ace84c3a941432681a66825f5572f066d0e7bfb40f4bbea4e63109ab715 remaining: 57351
# Processing: 4570-08 valve de Deaver L:300mm l:50mm c07013834c3ab94ec2c4f849fb03a3afb442231a3002b9973fe48e2eadb7008d remaining: 57350
# Processing: 64.231.25 clamp intestinal  Doyen courbe L:250mm e54d877041b5b01206ba8468b18e0fe17ebaa2537c5ba0b14b5bbcd6358e3162 remaining: 57349
# Processing: B605007 passe fil dissecteur Overholt-Slim courbe L:220mm 8707903c43eb754b622fbd76ae51c5d8305239623a97c10ca2462d82351fcc79 remaining: 57348
# Processing: B605005 passe fil dissecteur Overholt-Slim courbe L:205mm 4736393c0259ec27b1e905bacd89a2c069bc55ed119d272cb921e480f311a681 remaining: 57347
# Processing: C10718M pince à cadre L:220mm 9bc51f65e547a62935286e6c17cdd00255a55b685bb7513741b50b2a387785d0 remaining: 57346
# Processing: 6009-23 porte aiguille Jameson L:230mm 008c14909d4ca198eaf4137d68000f76477293484498080a953d350d3d0dcae9 remaining: 57345
# Processing: 31 manche pour miroir dentaire L:160mm a0ef0b8d470be23d37fa730f1bba500c80160787269244eb527d68dccf7dbc76 remaining: 57344
# Processing: 1869 instrument double L:180mm b48f9dc440ef832ef2b9c8454f4c099f6ad5170f62e05c2da334594d6dc1ec13 remaining: 57343
# Processing: 38-640-21 élévateur double L:210mm a4f43d835e84bed52be165ab1c21baef4d70479c9e10372999c35b52f11457b1 remaining: 57342
# Processing: 10203 élévateur L:160mm 576e9beeac5e43921dc96183d8368d05d31171b95a318d255783b78b76cd3880 remaining: 57341
# Processing: 72.08.13 abaisse langue L:140mm e92e082f16fb8b324679f41bfd6a70f981004139f90587e426090324f0b57d5f remaining: 57340
# Processing: 72.08.12 abaisse langue L:140mm ab59945d88dc6ae55d07415940f06c3d847a4292376e8fc28dc0925a0826375e remaining: 57339
# Processing: 72.08.11 abaisse langue L:140mm 8a1d44e77470d998480e004b6fa4f5f534d0787246ff9d10e2e5e0881cd754b6 remaining: 57338
# Processing: MCO ciseaux dissaction à poignée ouverte L:180mm e4a036e0bf3b92e2b8f7ca4d39c2fdfc867d953256d8bfe1a4ad988d7e5959ed remaining: 57337
# Processing: 05011 pince anatomique fine L:175mm 2*1 griffes 5627bf66003d7ffb5955360137586c74a55c8047212a72be83bcb0ec3ec205fc remaining: 57336
# Processing: 14424.00 décolleur double L:175mm d97f914eb3838c2f964c07f386fee3a93dd1cbcf8c5f76819b2723aaf1146ba4 remaining: 57335
# Processing: BF58 pince à pansements L:270mm 7986513fd649f12ef1e0201909d1d3ce339d2f330482502d65394335ba0d10eb remaining: 57334
# Processing: 92CP ciseaux droits L:140mm 2aca6ee1d416521ecc26d8d40e63054a88716c1925b17d361f3b20be2079165b remaining: 57333
# Processing: 11356-17 pince anatomique fine L:175mm 2*1 griffes 6e9b04b3dc5356b0f1671a5f927eeb8b1deed0c9a4e96f2fb3deecaf8be343df remaining: 57332
# Processing: BT178 écarteur Langenbeck-Green L:160mm 25*5mm 91ac14b335f4a721ea179fbccc4970ea7ab323598454e460c506ed907b6dfe58 remaining: 57331
# Processing: BT177 écarteur Langenbeck-Green L:160mm 15*5mm f46ca5ce1c995a7da73df9f607a943908863752ebf0292de0e778759a43b7a90 remaining: 57330
# Processing: 20.22.31 crochet dure-mère angle droit L:200mm bfa6dd5aa55c676755a7ea91f622deb168758371ee230373ceaf007608716825 remaining: 57329
# Processing: OM309 rugine de Williger L:155mm 144faf06b24fe82ce6836e1ca0c4d67790ff5bf3a8ec65122e64a7b2ffb1c3fc remaining: 57328
# Processing: 0403 pince anatomique manche rond L:160mm 2*1 griffes 00d5eaa4cde3ed36c47829de02a1c2b2523bbab607ab20671807eae26edb6987 remaining: 57327
# Processing: RH1010 rugine L:165mm 3e6b74b06682346e5bfe04a0683a14d8dd5255cce8921c8c9e869aa53084d3ad remaining: 57326
# Processing: 13-54800 écarteur L:160mm 373599ff0aaf662f4d3b4800fb228899931c8d906892e364b8e47a07cd86dedf remaining: 57325
# Processing: OP 316 ostéotome L:185mm ba37c3f169e0c96b7e65c24fd468ffb2e31f1b19aa591f316e93f69344198160 remaining: 57324
# Processing: 3004 râpe double D.3/4mm L:220mm 0511472f66788811241620b794694f57a130e9829b713e59e5d421ab212655ee remaining: 57323
# Processing: 5835 ciseaux angulés L:160mm f2f0a78d4050c6b8c4840d5aaed8cdddda532d1e8d445c40e94fac3cc8a6f8d1 remaining: 57322
# Processing: FF861 fraise L:70mm 97b3fece5fe5035ed232085a90d574ad2dc8baee5f7bcea56d512c2ed1276a42 remaining: 57321
# Processing: 04.130.10 crépine L:170mm 8a6814ea17dc913e15be3e8e22d12688e89631bc206a886afcd5a7505055e1c9 remaining: 57320
# Processing: RU 3290-04 pince Overholt courbe L:220mm 9d1b6455f8cc1cefc5c7642263a4bcc71cc0dcb6de72f26c14ad14a1ad3ba095 remaining: 57319
# Processing: B50835 pince O'Shaugnessy L:245mm d34a2d20fe5d838348abcb9e24bcd9741d7ead85afb3eb4e7ce88a791a9169a3 remaining: 57318
# Processing: 32-0350-11 porte aiguille Jameson L:230mm 493f478614e661e7542beeb1d3f6b6c91a2a99f524c8f723848af011fc0012f0 remaining: 57317
# Processing: 08 93 013 écarteur deLaborde L:145mm 49ad49942fb93d71c2da39b79f980443c9f31121ccdc6ee47969e8c386c9932a remaining: 57316
# Processing: BC274 ciseaux dissection droits L:200mm 11ee4f150d49fe4850425f2eeb414a2572834c66d329f9df637f8086afb539e8 remaining: 57315
# Processing: 1085/9 sonde L:155mm 7ec0ab37efb1c449267eea3b46720129db51426509bc70b059a8c973c26fdd83 remaining: 57314
# Processing: 45985 Miroir dentaire n°4 f8bec7fdb00f4d71c6e45adc44d051734fbe00357e40d4fbcd5bb9980534961c remaining: 57313
# Processing: 05440 élévateur manche rond L:180mm 422aec53f1645dcf08ca0144c24ef6725779b5dc7042eefabbbce476246bf19f remaining: 57312
# Processing: OM307 élévateur L:160mm 430c66e2a0345f4b8239c781e52f358d1d0139f9cefed5356954d4b925d776b7 remaining: 57311
# Processing: 72.08.20 ouvre bouche edda6fc63350e0861cd1794f2ca16bc8342c68c70b42e522e9d3acd5549066c6 remaining: 57310
# Processing: 7705.00 décolleur double L:170mm manche plastic 75c9a05438087ee554fb506e6c0ab44cc68fe7ec9a88845a6818e1219f7a75cf remaining: 57309
# Processing: 579 élévateur double L:200mm 51f2167aa981b101ea7054894764e00e534fb1ed779ece7f42a170d9d8ad26db remaining: 57308
# Processing: 52240-00 ouvre bouche 7fba3ff43540241ba1b5a2655a87883f66cd1d5eec6ec94ae6364d5a127ad6d5 remaining: 57307
# Processing: 871A/5A manche bistouri n°5 courbe L:150mm b1db9f22ce05438a9cbded1ecf59b0ebbfc75302e553ac0391b24904ea822ee0 remaining: 57306
# Processing: 1867/PR3 décolleur double L:195mm 9de108da7ce3db5e5fd6b0141717561f2bc63116bf667954f2941592b3d9bd09 remaining: 57305
# Processing: SR-58787 élévateur L:160mm 2cb7fa8b7fdaf42048bed3f0b8f8cf8ee5f809e5794d7ee93cfc08114f777320 remaining: 57304
# Processing: 9610-20 compas gradué b545ba5ba4f67575a352440bda7065e6865cb3f7e08cee25e32ab7f81c7ade35 remaining: 57303
# Processing: P-1592-13 ostéotome 13mm L:150mm 575f6a4348eb4304e69e89523d360f14e42c18de193b389ae793246c16d961f8 remaining: 57302
# Processing: 3006 râpe double D.5/6mm L:220mm cbd57fd1a3b9620040aff2d309c4c811454251a1c66a2e3841d4259193158a7e remaining: 57301
# Processing: 08-06015 râpe L:190mm c7ac133b9371800fb972aa143423f659c7bb9e3961d12d944833393b98b53be7 remaining: 57300
# Processing: 8123004 fraise multi ailettes L:70mm a0ffb4cc3d53e74d7e3e58ac876cc8fee09ba5f40ec3c4faa14ffb5e170be9e3 remaining: 57299
# Processing: 46410 crochet L:150mm ea9a15db0f09e52fcf69a102c703152e6bc1026c8cd9b5aeb07f53df255b25bc remaining: 57298
# Processing: 46409 crochet L:150mm a4894f5094c33b024d36247a078537cfbe23dea1d754f1356f1c4b476c471384 remaining: 57297
# Processing: 955 micro pince délicate L:125mm e5f97e7db18b36d8d72c6eef83334418b33d2bd0b58889c8f3f3a0b92e209359 remaining: 57296
# Processing: H4100 ciseaux délicats droits pointus L:105mm 10fe04d804889e8a697241fa6122271ca158bdcd81127ae09b7456648015c839 remaining: 57295
# Processing: 19130 Compas 0-15 0c4dc9002cabe6c8eec2266427a9632277bd6836682697941c662ab5104f2265 remaining: 57294
# Processing: 739.4180/B micro pince à préhension L:135mm e46a33a4f80b250abe00c7454ec4dce7b1f2f5f9652774b4b51cea2d2dc43f43 remaining: 57293
# Processing: 42903 ciseaux de Stevens courbes L:100mm e7029ad3b1a0caca95354b6cc0f79e95e89cbc3b18009ff8c518c3efc57d51c5 remaining: 57292
# Processing: 18790 pince anatomique délicate L:100mm 2*1 griffes f4944174956803a9890d05cebfa7b9b5a36449be4719c0e71de3e01db10efdab remaining: 57291
# Processing: 01.00501.011 écarteur de hohmann n°11 L:225mm f10be7be3dc316431c29e8a03b6d81533f7f2a6c479db433618a2e34e1cf508c remaining: 57290
# Processing: 75.26.05B écarteur fémoral L:320mm eacd81de3a16050b8205cf4eaf0c1aa224066ad266f7fba6eb7e083095ad39c0 remaining: 57289
# Processing: 10-911-01 crépine d'aspiration L:300mm 723032809bfdcb8b9af06a15377a91f701795a5df0b13b580ac22d558e890a47 remaining: 57288
# Processing: 01-08110 pince anatomique angulée L:180mm 75a25572b02b203227e1742a415d06aca845416f28ca7d6f8e8eee0b819bfd93 remaining: 57287
# Processing: 26002 câble unipolaire a276aa7ab4d021bc579912b485e2c61fea68a29f26ddde76fa224e8c2a715bad remaining: 57286
# Processing: MCEN 100-2-5 Aspirateur bleu 210mm 93ae43845a77a369e013929e6c910df0b0b4d936064d0b1d8708040627f7151f remaining: 57285
# Processing: 8150.17 canule d'aspiration courbe L:150mm D:3,2mm ebf47530f4f1ddfdba8611b8e668a8b44c7e75dfa9ba44c4cdb1690efb5c45f8 remaining: 57284
# Processing: 8471.23 trocart pour mandrin L:90mm 3c8f5b552946bd4b92103d9b8e9f54816cdbab22d09bda376f69e44cb090247a remaining: 57283
# Processing: 261500 décolleur L:170mm 1b8b10c834ee45996f9d8e1d26cde6e1b3e49da1fdbd9092e6be94d003c7cb1a remaining: 57282
# Processing: 330101 Pince préhension coudé fenestré L:190mm mors 3de0cd5c9f0db319087a4f20fa1d3b131dbfd4c2253d93caa74be7d5665645cf remaining: 57281
# Processing: 8211.131 pince nasale L:170mm 643929dba00cf1e735b4811a9c1bd07addda75f6f9a82b0fa25a04abef28f78e remaining: 57280
# Processing: 8211.14 pince nasale L:170mm eb4bbf3fcd0fffdff68a449ff117fda4dd8131b4d33cc632a3df49e0cd13bc45 remaining: 57279
# Processing: 8211.093 pince nasale L:160mm 9c0d279ec93699a1e61b549b951fc8af58d5aea5f2eef0f8f0af1d4a730297e9 remaining: 57278
# Processing: 8211.121 pince nasale L:190mm 3066849b5c995a0b9eaa2901722c8dc8f61dfcac369bc06c113e2920070e2b3b remaining: 57277
# Processing: 8211.08 pince à cloison L:210mm d6798400317d4e9fc49de2d4776905eb952f11b46ae00fe722bb471f37191883 remaining: 57276
# Processing: 7144A Porte aiguille L: 125mm 9c07e8a4df6bfa4fed2d23a1a0d354b512058ddb8b196644bba9390174783319 remaining: 57275
# Processing: 67.53.13 Ciseaux coudé L:140mm 6832883214c8e1b289024ea3e367dca494cbe62ad44c60eecd7ed5d7888e0e2c remaining: 57274
# Processing: 8211.29 spatule double graduée L:225mm 46a6de45ea1ee64161f2803dfb80d4abdf86300926789c9321e32de59f89e4f5 remaining: 57273
# Processing: 62.60.40 élévateur décolleur L:180mm e0ada6381bf37ed7cb313132c08de250a2a7c8b1b98b6eb48757a6b34af10e46 remaining: 57272
# Processing: 46.482.05 gouge pour cloison L:165mm l:5mm d2677f2a7029169e039e46359a103e8359ab722e681463e76553654df328f022 remaining: 57271
# Processing: 331001 pince nasale Luc L:200mm 9f2f1c26851f413bf185cc262ff8a81a36125dc11551a5c600df4fd7789d555d remaining: 57270
# Processing: 66.27.13 pince à cloison L:190mm bfc3c9e183ba7b749112aed55582cb5eaca8240aa4ab50ea78d046c2923d9b32 remaining: 57269
# Processing: 8211.21 ciseaux coudés L:185mm 74a522c7038531b50e2c4806a03efc0ac88b6c7592eb0a5dee79f40f985ffd79 remaining: 57268
# Processing: 8295391 bis Raccord UR lock pour pince à extraction corps étranger 6f46a3fd052aac15ae93c88b40d267e3b5c1283cb230edfa30e64d4c1f9e7b16 remaining: 57267
# Processing: 8295391 Raccord UR lock pour pince alligator 10378H 1d00384d895477ae8abb003db9a043cf9c28e28a0386cf14e2f0aa29b46e9237 remaining: 57266
# Processing: F10101 raccord L:45mm 0fc7133345cb8ecf03332dd463b6ff9cf075c67530b3650e71a505450948fdf6 remaining: 57265
# Processing: 10378K pince à extraction corps étrangers L:400mm 1b2dacc4f8f9772628eb273d94b4f7b8c74ca48f7035681b57f48578750bbed9 remaining: 57264
# Processing: 10378 H pince alligator L:400mm b5d1f2bb2170afe727d09eea28620223cd5c89adb29c15a47f323d0802f708a9 remaining: 57263
# Processing: 10338 CD tube bronchoscope 3,5x30 L:320mm 2e68a1ca0854e647c69996c3f1a42e05f3bea0fe8cd8e41b3ac92996ea78fbdc remaining: 57262
# Processing: 40-112-00 optique 0° 2654b65e250953cff41fc89f2a7b82d17609b645d6f60863dc9db571e0c3a7d8 remaining: 57261
# Processing: MCL17 pince à préhension L:300mm c115e54a7577789584d56bc0e05a5e86766aff1d96a8ea968671fb029e8d0ee6 remaining: 57260
# Processing: MCL11 pince à préhension L:300mm 2e5e1040f8c6b2dc803f43265346773fdf2c1f1c207f79c750002f629c97a0c8 remaining: 57259
# Processing: COA137 pince à préhension L:320mm 350b1dee32d0347f6e8ef20d915587843af393f277766f5c36a2665b31463cad remaining: 57258
# Processing: COA130 pince à préhension L:320mm e95c5e5835306f2f3d92202a46c6be7a8dbdbbf45d2560e32609c360c2d81d53 remaining: 57257
# Processing: COA129 pince à préhension L:320mm cf6600252fe1a8013326d2eecfe2ffc675892e0940d489c9f7b552536a2ff43a remaining: 57256
# Processing: COA127 pince à préhension L:320mm fda028a3c4a2127ddf7b0a5960e4f339971e035e3270730f5fa0a4289badf132 remaining: 57255
# Processing: COA126 pince à préhension L:320mm 29d92c35a9516fde4cc0108c7722cf0a28d00b4dc4d8b2326b44a0990579d769 remaining: 57254
# Processing: COA123 lame pointu vers le bas L:320mm 0c5a5f372a82b14314c2f37e36a06d9ef0294e59952f6653e76fe8f155e6183f remaining: 57253
# Processing: COA184 laryngoscope L:180mm 0276ded4a028a5965196c04dc2bcefdc29940d7019309d2f400900595c623184 remaining: 57252
# Processing: COA185 laryngoscope L:210mm 9c2723bb965f8359c5bc481afbc2edb485adfa7b5b3b2186ecc73bea09d385a2 remaining: 57251
# Processing: 8880.543 optique 30° D.4mm L:235mm e85b547c9b9ed92ea79dd5e7bf4130cc0693e2b1838f5c81027ca4ed6f27a516 remaining: 57250
# Processing: FB818 valve écarteur Finochietto L:100mm l:40mm 6dccbba0b30780e1b9ee9da06f9046eb9e6614894f26cebadd74ec23d89b0498 remaining: 57249
# Processing: FB817 valve écarteur Finochietto L:80mm l:45mm 792e79995ee3a69825dc3776459806e36b9bb04297acdbc6d81868addd867e4e remaining: 57248
# Processing: FB816 valve écarteur Finochietto L:80mm l:50mm 7014c6fdd6d388996555fafdcf6e858c3aae1f4d2785dd9c81576a4f92e538cf remaining: 57247
# Processing: FB814 écarteur Finochietto L:295mm l:225mm d288d0a39950adc4f768613795b0d9cfadb3a7ab706d180f74d9aa2bb765d239 remaining: 57246
# Processing: OF111 spéculum oreille H:35mm D:5mm a317dd49f8ce90e2d900ca6b10d51c679a29ffa94515daaf93d2103347d776a5 remaining: 57245
# Processing: 62.22.15 crépine d'aspiration L:140mm f72a8bff5d1aa936169af5521a8685e47fc4008058dbe9984b9163e095c60083 remaining: 57244
# Processing: 035300FX aspirateur L:150mm 7d644ce648bfe1f58867102b93f4b76144bf479f1d7fb6c2f01a08e5629af91b remaining: 57243
# Processing: OF115 spéculum oreille H:40mm D.2mm 02596db0e7d1b74a1816863786207ac0222a8b907c4059399b3aebb60802041f remaining: 57242
# Processing: 5453.00.5 Tête d'essai Ø 53mm 406044cbd35f22541b7ea017c3d5a87ed8c62f31658effdf2804f10ad26c16a5 remaining: 57241
# Processing: 5451.00.5 Tête d'essai Ø 51mm 9db010fdccf0d658f75aad888fa8da7672738a1a70dc2b05f37178dcbc876ad4 remaining: 57240
# Processing: 5449.00.5 Tête d'essai Ø 49mm 85342cfefba16bdf64fa433e772d032c89e15427ba2fc82d312709c512bcf758 remaining: 57239
# Processing: 5447.00.5 Tête d'essai Ø 47mm f85b2ebee2c62ae5f9e28747d18d8f6e2dd6acf70b3e0c20f652955b758c9049 remaining: 57238
# Processing: 5440.00.5 Tête d'essai Ø 45mm ad7279d2526e244c3bead72e89acb4490cc026b453c1b29054c04042681b8756 remaining: 57237
# Processing: 3017041-19 gaine métallique pour offset handle reamer L:290mm 256169508fc74493cf83c0fce1337f36e09470e6a836f3bc950c5a9ed7b13077 remaining: 57236
# Processing: 07-210-45 écarteur Verbrugge - Muller L:230mm l:45mm 3880799292dfa2ea68757f12405e93cc694783bae8a2e7c45d52ef2119b6ef05 remaining: 57235
# Processing: DB0114349 pièce en carbone L:80mm f6171c606b501bf861aebd819fefbdcc639a06919f5606ab7290d4d16270852c remaining: 57234
# Processing: DB0116121 viseur en carbone 982176459d3dd5af51efdf8533539c5bd12f2c10c8256de26e54cf3925b6eba2 remaining: 57233
# Processing: 28-1539-01 1,8mm punch for use with 2,8mm anchor L:220mm 1ce8a8127d47a1248c78321fd9622f798bdf999dabcb4fa93ed2b812da84edfc remaining: 57232
# Processing: RU 5350-10 curette n°0 L:170mm 22b9f5f37ca921f766cf242fb2cf729bafd9d43030c999a4105a24a1a3d4b953 remaining: 57231
# Processing: 33204 pince gouge 4mm L:170mm 3691600dd4946d278bbdf85ec85d0e0909861217c72c7e742eece606624cc9c8 remaining: 57230
# Processing: l99-l05 écarteur Farabeuf Langenbeck L:205mm baa1fa1dbcc567ab18f897b696a91d97e81701a4ef53ce12742f33f667f68eb7 remaining: 57229
# Processing: BF306 pince Ombredanne L:160mm 6b5d66f5b81ae8696984c53328c69d2dba5cdc7c3be2effdc2dbe940bca03e26 remaining: 57228
# Processing: 39707 Porte-aiguille Crile Wood L: 230mm 7510f04830430a6167ab159f055e558075227ca9fd9c8455cb7779391fc9accf remaining: 57227
# Processing: 10.18.70 porte aiguille L:210mm e4863ed24c819c62fb5a37a15df855211d80f7c260af47e3368a60286c7c9684 remaining: 57226
# Processing: 04704 ciseaux dissection Sims courbes L:200mm f8726f05ce1fc62c45cc4239827800a18132f6cb9c0484315cb9729ce39d75c1 remaining: 57225
# Processing: 32504 pince gouge L:150mm 9c120f8960b3b43bfcedb693db111ed1dcda3eea0a1a77e0ccdd50bf7bfaa122 remaining: 57224
# Processing: 251H05 écarteur de Parker-Langenbeck L:210mm 52b4e1243970a9d837df30cb80e224d92b290cac4975532effdf67711bb750ba remaining: 57223
# Processing: 40.521.17 davier de Setter L:170mm 2b43e377c9c9312b2a2a6193a6ded1cdd91453abc5e13b5954c029cf089d03d4 remaining: 57222
# ...
# Processing: 413.342 LOCKSCR Ø5 SELF-TAP L42 TAN a7dc34676a8ed625bf85f04495e854224c601dc4b865c1528e4e231fa5d71024 remaining: 54262
# Processing: 413.332 LOCKSCR Ø5 SELF-TAP L32 TAN 6db5869be773d7435a906835652c77375daa5016451ff07ceaddf2ca05cd4a9b remaining: 54261
# Processing: 413.326 LOCKSCR Ø5 SELF-TAP L26 TAN 24b49fe3c6c235b1efe9e6ea18c984bd5cc2a7a6e74d6f0a378f659b9f028126 remaining: 54260
# Processing: 413.322 LOCKSCR Ø5 SELF-TAP L22 TAN 66acc266397d07c08706af531f230031d7cf75b13ffc96f155708903a0309118 remaining: 54259
# Processing: 413.318 LOCKSCR Ø5 SELF-TAP L18 TAN 064c035bf2968eae240f8b929f43a0bdd263dc000bf27fb02bb1b38de472ba09 remaining: 54258
# Processing: 413.316 LOCKSCR Ø5 SELF-TAP L16 TAN c291977cf453dfdad5a10c3edda4e3a482d54ad500de15c5593513f1a2e49c39 remaining: 54257
# Processing: 413.314 LOCKSCR Ø5 SELF-TAP L14 TAN 8daf90910370d997880d0de0666f02364a476ac9452e0f65f4302f78e8eda08e remaining: 54256
# Processing: 681.245 SCRRACK F/LOCK SCR Ø5 SELF-TAP W/LID W/O b44cb9c95bb83f4bfc45fdb5c89999e400eac09a69f9fd3b28da86f9a8adbaa4 remaining: 54255
# Processing: 329.020 BEND-IRON F/LC-DCP 4.5+DCP 4.5 L250 acd58ec4b86e08b73d4b4ba041005ac6c151a3f4460198eb850f7c7820b7ebff remaining: 54254
# Processing: 511.774 TORQUE LIMITER 4NM F/AO/ASIF F/REAMERS 20ad06c634b45f152fca45729c30b4eb24bfeee28aef03896b9b7c38d50a89d0 remaining: 54253
# Processing: 397.706 HAND F/TORQUE LIMITER NO. 511.774 023af02c7b0d648c8f0d42f5fb9bab83dc1ab1821bb6a8fc7c4ddd55c7425789 remaining: 54252
# Processing: 314.270 SCRDRIVER-HEX-LRG Ø3.5 W/GROOVE L245 910b8cd878637ef2859fe64dd6c02437156264dbe8d03ad0ce2afd8076b1be24 remaining: 54251
# Processing: 310.290 DRILL BIT Ø3.2 L195/170 2FLUTE F/QC 502a55a5c7d944131a042a0629267d1a0f5af621a93304ed52719fd251a90fbd remaining: 54250
# Processing: 310.430 LCP DRILL BIT Ø4.3 W/STOP L221 2FLUTE F/ d72716c80231d06abafe21ada5cfd847a980734b7767fe1367d773932cee9283 remaining: 54249
# Processing: 319.100 DEPTH GAUGE F/SCR Ø4.5-6.5 MEAS-RANGE UP (4 pièces) 0fa8bfd7f008ded599f717021f36cd1281132af698d7c1d1eeabca0e8451888c remaining: 54248
# Processing: 689.547 VC FRAMING W/BOTTOM SIZ 1/1 H88 8c06e1193a4579f1d0f5c003811f8a81ab35afec7f594b2e139be59682676939 remaining: 54247
# Processing: 414.844 CORTSCR Ø4.5 SELF-TAP L44 TI 4b90947802d1e06928921d4b036adceb69dcc7e23de53fa7f966e3f4ed2838ab remaining: 54246
# Processing: 414.840 CORTSCR Ø4.5 SELF-TAP L40 TI a107670872fd33e5a7fe0648a7ca35e04ae56e8088d4af9545166291406ff848 remaining: 54245
# Processing: 414.838 CORTSCR Ø4.5 SELF-TAP L38 TI 4bd2c733ee41a4be3d9ffc63b05d092ebb51e80545f1ac7c780e8de949db1694 remaining: 54244
# Processing: 414.836 CORTSCR Ø4.5 SELF-TAP L36 TI c577cd53d8fb9ca7d6e6be382a617c8f2ed75e5d700efc815fde8e870ea8623b remaining: 54243
# Processing: 414.832 CORTSCR Ø4.5 SELF-TAP L32 TI 58e0a87fd321fda6f00d25f4a8b72ba3b579bb5c5ad1a1dc7b3d567a4dcd1427 remaining: 54242
# Processing: 414.830 CORTSCR Ø4.5 SELF-TAP L30 TI 41bf6467f895051b1494b7b62d4b97765e646a39b6b67885f99234cf54af1574 remaining: 54241
# Processing: 414.828 CORTSCR Ø4.5 SELF-TAP L28 TI 07d87acb7487bc9cc23ecc00df362b84f9e95d1db82a9a1b412ecd5ccaa71882 remaining: 54240
# Processing: 414.826 CORTSCR Ø4.5 SELF-TAP L26 TI cf419c9e018009604da2b9c2c3358ef6e09d777272b94668c51c4c77895d1634 remaining: 54239
# Processing: 414.822 CORTSCR Ø4.5 SELF-TAP L22 TI 257e31b37a7b03e4e4c22b25155570d31674c3937de225b564fff830c90aec50 remaining: 54238
# Processing: 414.820 CORTSCR Ø4.5 SELF-TAP L20 TI 143a042a3978f07b777868c586ed882f49da0020c156b0704dc2f56f45558ec2 remaining: 54237
# Processing: 414.818 CORTSCR Ø4.5 SELF-TAP L18 TI 6d3936f7167e91c89f5e9d65a309f3a0fa2e1852e89536ef946c9665f22add5f remaining: 54236
# Processing: 407.050 CANCELLOUSSCR Ø4 L50/15 TI 9095dd9fb8890241b1184f4008ba5f85a40be28f05fbf9665eb8d7b090d71af8 remaining: 54235
# Processing: 407.045 CANCELLOUSSCR Ø4 L45/15 TI 8794d39d462f724b439dda5bcae536b170550774f32dbe9319f14869e1440851 remaining: 54234
# Processing: 407.040 CANCELLOUSSCR Ø4 L40/14 TI 11a5dd105f112efa97d8390b9524b1fd978cc2a4276ae759ea23d2e7374d4b0e remaining: 54233
# Processing: 407.035 CANCELLOUSSCR Ø4 L35/14 TI 75c63f6e80c4068cba05025631f3607bf9356bce4da0f4724ebe178f6766954b remaining: 54232
# Processing: 407.030 CANCELLOUSSCR Ø4 L30/14 TI 9884950683af68954cc7c901dbb85138218f326a1268d929c2fa28144bead3b3 remaining: 54231
# Processing: 407.028 CANCELLOUSSCR Ø4 L28/14 TI c63943ea8650f7f240d8fb7521b9cea60574b4e5ced2ca9e522e05fa62635096 remaining: 54230
# Processing: 407.026 CANCELLOUSSCR Ø4 L26/12 TI 90cd8c12e81001253d5dfc05c7a7849377f4bfcd7c3c5e915485eb273229784a remaining: 54229
# Processing: 407.022 CANCELLOUSSCR Ø4 L22/9 TI b7fcba70591489dc524e3551666c1e7f1d739055af37489314cce02196ac6298 remaining: 54228
# Processing: 407.020 CANCELLOUSSCR Ø4 L20/8 TI c3300b8fd6eda0610ed0b5dccff60fd9dc3781f8937cca0354c2a366d21ca516 remaining: 54227
# Processing: 404.850 CORTSCR Ø3.5 SELF-TAP L50 TI 6547f649e829054663a72ad892033d4732b80323511bee95303d96e29ccab26f remaining: 54226
# Processing: 404.845 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN c8d151c261177505f9712c84948f58c87cf61f3ce090650fe200b9f2cecec481 remaining: 54225
# Processing: 404.838 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 867eb30480d1e3aa9583d6cbb3f3fa36adf8ef7db4a876bcf8843c0c00c4e367 remaining: 54224
# Processing: 404.836 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 61f4a97cc58122b349e44e29413dd0a7df588c7081aed44e8f05e8dd8e5a10ae remaining: 54223
# Processing: 404.818 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 5e6438708b16bd2ec4ffc74abe1e5b42524a66caa356c604a66af42552dd6dc1 remaining: 54222
# Processing: 404.816 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN e94e77b048bc133ad320139ddd705120d4dc902d0cfa6af2ec8627a64bdaad26 remaining: 54221
# Processing: 404.814 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 8db5d70da9eae175a9391685a84dac692bab0ba83b82eecfc31f4e72f79ced44 remaining: 54220
# Processing: 413.055 LOCKSCR Ø3.5 SELF-TAP L55 TAN 5c00b3afe9a1d490f31203bed9e7ef547ecf2a5e3bea188f62833e902158717c remaining: 54219
# Processing: 413.040 LOCKSCR Ø3.5 SELF-TAP L40 TAN f8c83e05f06eb6c171bd2f42a0ec64c6cfffae1ef4f7080b4fa388f2f68c7e07 remaining: 54218
# Processing: 413.036 LOCKSCR Ø3.5 SELF-TAP L36 TAN 77cba328de4bc0fdc4456377d94036d1647d0bb73f95c546e2f6e3159cdba79c remaining: 54217
# Processing: 413.034 LOCKSCR Ø3.5 SELF-TAP L34 TAN cd5bf14debd162b982b630fe27f1bab11524f7118a7d5948c6b663e38e9f25db remaining: 54216
# Processing: 413.032 LOCKSCR Ø3.5 SELF-TAP L32 TAN 1bb2ce80ae8ac44747fd51434516cddd9027e01e5103e294b745831722d6cb81 remaining: 54215
# Processing: 413.028 LOCKSCR Ø3.5 SELF-TAP L28 TAN f9e460f601e356df98909d0206d206a3ddec87d7da68385d6bc062ea25c25c87 remaining: 54214
# Processing: 413.024 LOCKSCR Ø3.5 SELF-TAP L24 TAN 6f5b34ad2a31bfb6f6354fbb3f70cd896cf6006d1d4acd0ad82edf24d990685f remaining: 54213
# Processing: 413.022 LOCKSCR Ø3.5 SELF-TAP L22 TAN 8d1dd8f57981f9e937904114099f790f17c9a05b19a717abbe2cc48890277315 remaining: 54212
# Processing: 413.020 LOCKSCR Ø3.5 SELF-TAP L20 TAN 0e518b401a7548266f06e5025edb73df0816e878c652a6bc784f201138cf0b5c remaining: 54211
# Processing: 413.018 LOCKSCR Ø3.5 SELF-TAP L18 TAN d70c14d546b41c46274e15dcc60f1d0216809453b6a71136916cd3d9aa2e6e3b remaining: 54210
# Processing: 413.016 LOCKSCR Ø3.5 SELF-TAP L16 TAN 1fefe75db6901c39fc575eb54de8ffa7dd153e4214291086f42e1f9c84a95d72 remaining: 54209
# Processing: 413.012 LOCKSCR Ø3.5 SELF-TAP L12 TAN 6146170e267ab9095016e48b64cb26c717e3347c50ddf26ed2b6c502eb6bfa79 remaining: 54208
# Processing: 68.000.111 SCREW RACK SIZ ½ H77 6ebdf9eaef5a003b9af24081ca4097b58d4af4d089b01f1ddea379b2f6b70b62 remaining: 54207
# Processing: 404.834 CORTSCR Ø3.5 SELF-TAP L34 TI d96bee548efeb45c000e4b8ea7324eaa4b09d65df57cbe68bc16946fa56e77dd remaining: 54206
# Processing: 404.832 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN d709951bd646464066f80c939e2e39cc5daeffa28614eb1c8d19eef3b854ceba remaining: 54205
# Processing: 404.830 CORTSCR Ø3.5 SELF-TAP L30 TI e0c5836fd342ebccd2cd92e546d5e1c5dc324266835419ea55521c75590de275 remaining: 54204
# Processing: 404.828 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN b343db56005fd31a636e56dab9815e010d4d37245a2f8136cb466c4866355b7d remaining: 54203
# Processing: 404.826 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 319fbf5c08b3c50b580443f11fd0a2ec172eda5f299970d59a77103d4eda4b5e remaining: 54202
# Processing: 404.824 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 47d1749696d4c7c0733c439364de52af8e34df5840d49b179c04ea4c400d2eef remaining: 54201
# Processing: 404.822 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN 69aca6c92556f0726b2f6a6370df805603077efdf230566b7efbaa20dc46246b remaining: 54200
# Processing: 404.820 CORTSCR Ø3.5 SELF-TAP L20 TI 999fab70bcf3a61432c43d3d8c4933f595c6f4d5021403f402fe5b1f6e5978ff remaining: 54199
# Processing: 404.812 CORTEX SCREW Ø 3.5 MM SELF-TAPPING LEN ebf7c68546634d86b4c40d85445e29948f5e5b8d8d76eb99ae0a2416ebe90673 remaining: 54198
# Processing: 404.810 CORTSCR Ø3.5 SELF-TAP L10 TI efd7a9a61b595de9e1f8d3e14766a6b68406dff097089c4c65c9509fcce66575 remaining: 54197
# Processing: 413.050 LOCKSCR Ø3.5 SELF-TAP L50 TAN a61948f268e65f53a0dd91eddc70961d17a20f967fbbb9ba158868bf76b2fbfc remaining: 54196
# Processing: 413.045 LOCKSCR Ø3.5 SELF-TAP L45 TAN aa5953ec322dbe90028a6fb719c6be42ea30b3c55af06a881ec327f6d05a0c27 remaining: 54195
# Processing: 413.038 LOCKSCR Ø3.5 SELF-TAP L38 TAN fb2f3e32eed0ee32bfffa907f32fd90172d42312ad7d904446f41280b691db2e remaining: 54194
# Processing: 413.030 LOCKSCR Ø3.5 SELF-TAP L30 TAN fa8aeeffc5c4ebba8600776bd1eb2983ecff6b158c1a85f1ac02b12f5fc408ec remaining: 54193
# Processing: 413.014 LOCKSCR Ø3.5 SELF-TAP L14 TAN 12f8b5170a0ec2962ec6da90d6be263559cc9a3f8b05dc6bd5a9a9a5bd7e2557 remaining: 54192
# Processing: 311.440 T-HANDLE W/QUICK-COUPL 42a1b7f98bd7f9888b12cb95dff8ca920a4293984fd0748db2287b18d8e9b042 remaining: 54191
# Processing: 311.320 TAP F/CORTSCR Ø3.5 L110/50 6e14e7143fa8c67c41b2b8f60e7d7106adecaefc95d257db678d86149a4a969b remaining: 54190
# Processing: 314.090 HOLD-SL F/314.070 314.550+314.570 (4 pièces) 5f690029231382183b6beb983c89427fc1e88513dd33316f875628f5a42567df remaining: 54189
# Processing: 68.122.013 MODULAR TRAY F/SM-FRAGM-BASIC INSTR SIZ 156e5eb9e24ff043aa11277e1748cf503c4bc169060f1cf18678d63f978dfe49 remaining: 54188
# Processing: 312.937 AIMING BLOCK F/LCP METAPHYS-PL F/DIST-TIB LE 3be1aeab00a3181a6a50214bc6514a20af8b5bf6065d8df73a16269ad02600dd remaining: 54187
# Processing: 329.916 BEND-PIN F/LCP-PL 3.5 d8d0e4cedb85051ca7c463dc6ae82552c123a68827374ee023a9b6513dbf2170 remaining: 54186
# Processing: 314.091 HOLD-SL F/SCR F/LCP 3.5 (4 pièces) 8e216ad81ab82aa13157480afd861f4a1b3ca1634ff9d79d0b3b99d075b6ed41 remaining: 54185
# Processing: 441.351 LCP 1/3-TUB-PL 3.5 5HO L64 TI 362ddde86d3a4f1ece74a9651ffb709bfec1703fb0dddd99af547048dea6cea1 remaining: 54184
# Processing: 441.361 LCP 1/3-TUB-PL 3.5 6HO L76 TI 8f9c90314f802164de43abbdc8af34e19d32189a184c5c34c75bda9ce9b76c08 remaining: 54183
# Processing: 441.371 LCP 1/3-TUB-PL 3.5 7HO L88 TI b2b1d6764f1508e1d10638efbcff92df0a81604e9d0b10bd8a68d665f8474ecf remaining: 54182
# Processing: 423.412 LCP METAPHYSPL 3.5 12HO L164 TI 96534b0f0b8aa6000af70e07919925d47f2522d491fcdf85b6f810fbec28c240 remaining: 54181
# Processing: 423.416 LCP METAPHYSPL 3.5 16HO L216 TI 859dc7e3953549667493be5b5aa2080ca0085fd5b8fdac77dbbf079bbcfcede3 remaining: 54180
# Processing: 423.418 LCP METAPHYSPL 3.5 18HO L242 TI 6e2868b752fc47458d8cd7e6ff9c98baff83b550e7db3eea71318e43f4fdaeb1 remaining: 54179
# Processing: 424.765 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+15HO L334 724c3ae95542ebbb564c75f90bdc9e825cf52d25ce69998c5435f125b45c30d7 remaining: 54178
# Processing: 424.761 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+11HO L262 b45f4a9c4200240ad073ff9f599c1d59fbb40956fbceb144aaf374138a429aca remaining: 54177
# Processing: 424.759 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+9HO L226 1f3f8d65ce95b27a4b9c231121d08fcaa8f3ea8770a103203add7acf4fee37eb remaining: 54176
# Processing: 424.758 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+8HO L208 fe7d95f5a317750d8a01f5e58b102cefd5c2ab21b91ed7137c5805278dafa7b2 remaining: 54175
# Processing: 424.757 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+7HO L190 e4222257ff6c977b9fc9b7c2531be605b2a4b1192bf86db3d3f19d1d7f5294cf remaining: 54174
# Processing: 424.755 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+5HO L154 375d274a34d79d76242febff7ade501d75c736d58bbbb0e40d63fc7919b2da23 remaining: 54173
# Processing: 424.753 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+3HO L118 c1b3c424f6d77a9fded1ae2bf691ef8c01457f7da0de6c1eeb379764d9e3b023 remaining: 54172
# Processing: 424.770 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+6HO L159 d1d47cf9d30aa1470e5cfcbffc7e953047c730faa17f55fd5deac9a3317bf914 remaining: 54171
# Processing: 424.772 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+8HO L195 a3b86f1cdf7bc27e0e8b716509068e82204281053dec9d8708bffea316d69054 remaining: 54170
# Processing: 424.778 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+14HO L303 c2160dbf82344e7ef23a5db03ae6d53211b44de7afc0a605873ecceced03fcdd remaining: 54169
# Processing: 424.780 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+16HO L339 d3ae91ae7f6a2ccc8c81e5b98507b89e9e7b6742e13bfe562c4ab9ece214e417 remaining: 54168
# Processing: 423.410 LCP METAPHYSPL 3.5 10HO L138 TI 9c531a000200b805050520850ff7f366e2c81815a061915a4b9dd57145b3bdce remaining: 54167
# Processing: 424.763 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+13HO L298 744ff08f8f48e09bbae32051ca9d711374aebba12cf7079285a8d7d578b9671d remaining: 54166
# Processing: 424.756 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+6HO L172 98a20c5e6ed2276c81708589534f5e19e02d93453a08943260880dfbf3413d2e remaining: 54165
# Processing: 424.754 LCP METAPHYSPL 3.5/4.5/5 BROAD 5+4HO L136 790731a6b8dbcdbce6e61c20a7840c97e24d46fe5fb68b1bb096cca6b9196f83 remaining: 54164
# Processing: 424.768 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+4HO L123 85cb97f14e8701875f8239ea7fd5c607d2c2210374fad4526f3e4de2fe1be325 remaining: 54163
# Processing: 424.769 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+5HO L141 b1d25b859c4ba781fb797be8646cc6c0505ee95e6269aab2303b33798c39dd55 remaining: 54162
# Processing: 424.773 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+9HO L213 64a64e4b175bf7473c3d2456a3093d736b0cd5e08f3d2019e2f280ac93379aff remaining: 54161
# Processing: 424.774 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+10HO L231 3a300c55525596106337303541140ab209899d9b87414329f4d73b7a042a0ca0 remaining: 54160
# Processing: 424.776 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+12HO L267 c9dadeed10fda21b8af8f75b1f38c05ab39c1f1774dcb6f710e7f0f146b0ccff remaining: 54159
# Processing: 424.784 LCP METAPHPL 3.5/4.5/5 F/DIST-TIB R 4+20HO L411 5a342ebc8194b975d959c8fd3b4e941768c0f847246edd268d99bfd4f15d7708 remaining: 54158
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In [22], line 73
#      70         _count -= 1
#      71         del _comp_id_lookup_dict[_componentidentifier_two_hash]
# ---> 73 process_component()
#
# Cell In [22], line 58, in process_component()
#      56     _similar_componentidentifiers[_componentidentifier_one_hash] = []
#      57     _similar_componentidentifiers[_componentidentifier_one_hash].append((_componentidentifier_one_hash, _componentidentifier_one, _componentname_one))
# ---> 58     save_similar_component(str(_componentidentifier_one_hash), str(_componentidentifier_two_hash), True, False)
#      61 if _componentidentifier_two not in _similar_componentidentifiers[_componentidentifier_one_hash]:
#      62     _similar_componentidentifiers[_componentidentifier_one_hash].append((_componentidentifier_two, _componentidentifier_two_hash))
#
# Cell In [9], line 30, in save_similar_component(master_article_hash, article_hash, id_linked, name_linked)
#       5 query = (f"""
#       6         if not exists (
#       7         select master_article_hash
#    (...)
#      27         )
#      28         """)
#      29 with conn.cursor() as cursor:
# ---> 30     cursor.execute(query)
#      31     conn.commit()
#
# Error: ('01000', '[01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionWrite (send()). (10054) (SQLExecDirectW); [01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]General network error. Check your network documentation. (11)')
